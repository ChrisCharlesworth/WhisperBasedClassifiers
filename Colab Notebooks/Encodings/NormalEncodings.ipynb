# %%
# !pip install transformers
# !pip install peft
# !pip install -i https://pypi.org/simple/ bitsandbytes
# !pip install accelerate
from transformers import WhisperProcessor, WhisperForConditionalGeneration
from peft import PeftConfig, PeftModel
import torch
import bitsandbytes
import accelerate
import json
from google.colab import drive
import librosa
from transformers import WhisperForConditionalGeneration, AutoProcessor
import os
from transformers import WhisperForConditionalGeneration, AutoProcessor
import torch
import librosa
from tqdm import tqdm
from pathlib import Path
import json
import numpy as np
import wave
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Collecting peft
#   Downloading peft-0.11.1-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.3.0+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft) (4.41.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft) (4.66.4)
# Collecting accelerate>=0.21.0 (from peft)
#   Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft) (0.4.3)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.23.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13.0->peft)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13.0->peft)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13.0->peft)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13.0->peft)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13.0->peft)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ERROR: Operation cancelled by user
# Looking in indexes: https://pypi.org/simple/
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl (119.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━ 114.1/119.8 MB 160.1 MB/s eta 0:00:01

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Define the model ID on the Hugging Face Hub
# peft_model_id = "mirella-guenther/openai-whisper-large-v3-torgo-2-epochs"

# # Load the PEFT configuration from the Hugging Face Hub
# peft_config = PeftConfig.from_pretrained(peft_model_id)
# processor = WhisperProcessor.from_pretrained(peft_config.base_model_name_or_path)

# # Determine the device and data type
# device = "cuda" if torch.cuda.is_available() else "cpu"
# dtype = torch.float16
# # if device == "cuda" else torch.float32

# # Load the Whisper model for conditional generation
# model = WhisperForConditionalGeneration.from_pretrained(
#     peft_config.base_model_name_or_path,
#     # load_in_8bit=True,
#     device_map="auto",
#     torch_dtype=dtype
# )

# # Apply the PEFT model
# # model = PeftModel.from_pretrained(model, peft_model_id)
# model.to(device)
# print("Whisper model loaded successfully.")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/771 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.90k [00:00<?, ?B/s]
# Whisper model loaded successfully.

# %%
file_path = '/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/0015.wav'

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-large-v3", torch_dtype=torch.bfloat16).to(device)
processor = AutoProcessor.from_pretrained("openai/whisper-large-v3")
# audio, sr = librosa.load(file_path, sr=None)
# input = normal_processor(audio, return_tensors="pt", return_attention_mask=True, sampling_rate=16000)
# input = input.to(device)  # Move the input tensors to the same device as the model
# input = input.to(dtype=torch.bfloat16)  # Ensure the input tensors are of type BFloat16
# normal_output = normal_model.model.encoder(**input, output_hidden_states=True)
# output_2 = normal_model.model.encoder(**input, output_hidden_states=True)
# input = {k: v.to(device, dtype=torch.float16) for k, v in input.items()}
# output = model.model.encoder(**input, output_hidden_states=True)
# print(normal_output.last_hidden_state[0])
# print(output_2.last_hidden_state[0])
# print(output.last_hidden_state[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.90k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
current_dir = os.getcwd()
# Navigate to the parent directory
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))

# Define the path to the data folder
# data_folder = os.path.join(parent_dir, "data")

data_folder = '/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO'

def get_wav_duration(file_path):
    with wave.open(file_path, 'r') as wav_file:
        frames = wav_file.getnframes()
        rate = wav_file.getframerate()
        duration = frames / float(rate)
    return duration

def find_wav_files(directory):
    wav_files = []
    # Iterate over all items (files and directories) in the current directory
    for item in os.listdir(directory):
        # Construct the full path
        item_path = os.path.join(directory, item)
        # If it's a file and ends with .wav, and there's no 'C' in the path, and duration is longer than 2 seconds, add it to the list
        if os.path.isfile(item_path) and item.lower().endswith(".wav"):
            if get_wav_duration(item_path) > 2.5:
                file = item_path
                if ('MC01' in file or 'FCO1' in file or 'MC04/Session1' in file or 'F04' in file or
                'M03' in file or 'F01' in file or 'M05' in file or 'F03' in file or
                 'M01' in file or 'M02' in file or 'M04' in file):
                    wav_files.append(item_path)
        # If it's a directory, recursively call the function
        elif os.path.isdir(item_path):
            wav_files.extend(find_wav_files(item_path))
    return wav_files

wav_files = find_wav_files(data_folder)
print(len(wav_files))
# Out:
# 3672

# %%
class_names = []
for i, file in enumerate(wav_files):
    # if ('MC' in file or 'FC01' in file):
        #  or 'FC' in file or 'Healthy' in file):
    if ('MC01' in file or 'FCO1' in file or 'MC04/Session1' in file):
        class_names.append('Healthy')
    elif ('F04' in file or 'M03' in file):
        class_names.append('VeryLow')
    elif ('M05' in file or 'F03' in file ):
        class_names.append('Low')
    elif ('F01' in file or 'M01' in file
          or 'M02' in file or 'M04' in file):
        class_names.append('Medium')

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

# directory = Path.cwd().parent.as_posix() + '/data/small_dataset'

audios = []
file_names = []
print('reading audio')
output_file_name = "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Embeddings_Normal_New_2.json"
output_folder = "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2"
with open(output_file_name, 'w') as json_file:
    json_file.write("[")  # Start of the JSON array
    # Iterate over files in the directory
    file_counter = 0
    for i, file_path in enumerate(wav_files):
        if file_path.endswith(".wav"):
            audio, sr = librosa.load(file_path, sr=None)
            # audios.append(audio)
            input = processor(audio, return_tensors="pt", return_attention_mask=True, sampling_rate=16000)
            # input = {k: v.to(device, dtype=torch.float16) for k, v in input.items()}
            file_names.append(file_path)
            output = model.model.encoder(**{k: v.to(device, dtype=torch.bfloat16) for k, v in input.items()}, output_hidden_states=True)
            # model.model.encoder(**input, output_hidden_states=True)
            # model.model.encoder(**input.to(dtype=torch.bfloat16), output_hidden_states=True)
            your_tensor = output.last_hidden_state[0].to(dtype=torch.float16)

            # Convert the tensor to a supported data type (e.g., float32) before converting to NumPy array
            your_tensor = your_tensor.float()  # Convert to float32
            # numpy_array = your_tensor.detach().numpy()
            numpy_array = your_tensor.detach().cpu().numpy()

            # ONLY TAKE FIRST 375 ie. first 7.5 seconds
            numpy_array = numpy_array[:375, :]

            if file_counter > 0:
               json_file.write(", ")  # Add comma before each element except the first one
            json.dump({"fileName": file_path, "numpyArray": numpy_array.tolist()}, json_file)

            file_name = str(i) +  ".json"
            entry_json_file_path = os.path.join(output_folder, file_name)
            with open(entry_json_file_path, 'x') as json_entry_file:
                json.dump({"numpyArray": numpy_array.tolist(), "className": class_names[i]}, json_entry_file)

            print('Written to json for file ' + file_path + ' which is file number ' +  str(file_counter))
            file_counter += 1
    json_file.write("]")  # End of the JSON array
# Out:
# cuda
# reading audio
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0020.wav which is file number 0
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0127.wav which is file number 1
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0078.wav which is file number 2
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0077.wav which is file number 3
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0104.wav which is file number 4
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0031.wav which is file number 5
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0036.wav which is file number 6
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0027.wav which is file number 7
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0055.wav which is file number 8
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0004.wav which is file number 9
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0120.wav which is file number 10
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0067.wav which is file number 11
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0003.wav which is file number 12
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0008.wav which is file number 13
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0005.wav which is file number 14
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0037.wav which is file number 15
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0068.wav which is file number 16
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0130.wav which is file number 17
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0021.wav which is file number 18
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0126.wav which is file number 19
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0030.wav which is file number 20
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0106.wav which is file number 21
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0022.wav which is file number 22
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0028.wav which is file number 23
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0001.wav which is file number 24
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0105.wav which is file number 25
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0093.wav which is file number 26
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0114.wav which is file number 27
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0014.wav which is file number 28
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0002.wav which is file number 29
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0032.wav which is file number 30
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0056.wav which is file number 31
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0132.wav which is file number 32
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0096.wav which is file number 33
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0035.wav which is file number 34
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0116.wav which is file number 35
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F01/Session1/wav_arrayMic/0023.wav which is file number 36
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0130.wav which is file number 37
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0145.wav which is file number 38
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0061.wav which is file number 39
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0177.wav which is file number 40
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0069.wav which is file number 41
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0005.wav which is file number 42
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0092.wav which is file number 43
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0015.wav which is file number 44
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0043.wav which is file number 45
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0038.wav which is file number 46
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0166.wav which is file number 47
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0131.wav which is file number 48
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0027.wav which is file number 49
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0077.wav which is file number 50
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0121.wav which is file number 51
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0002.wav which is file number 52
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0160.wav which is file number 53
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0192.wav which is file number 54
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0067.wav which is file number 55
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0042.wav which is file number 56
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0120.wav which is file number 57
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0184.wav which is file number 58
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0091.wav which is file number 59
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0003.wav which is file number 60
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0180.wav which is file number 61
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0049.wav which is file number 62
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0063.wav which is file number 63
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0198.wav which is file number 64
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0164.wav which is file number 65
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0196.wav which is file number 66
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0004.wav which is file number 67
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0147.wav which is file number 68
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0112.wav which is file number 69
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0191.wav which is file number 70
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0116.wav which is file number 71
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0071.wav which is file number 72
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0174.wav which is file number 73
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0046.wav which is file number 74
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0025.wav which is file number 75
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0001.wav which is file number 76
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0050.wav which is file number 77
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0088.wav which is file number 78
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0100.wav which is file number 79
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0107.wav which is file number 80
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0006.wav which is file number 81
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0034.wav which is file number 82
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0159.wav which is file number 83
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0150.wav which is file number 84
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0119.wav which is file number 85
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0197.wav which is file number 86
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0065.wav which is file number 87
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0133.wav which is file number 88
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session1/wav_arrayMic/0148.wav which is file number 89
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0145.wav which is file number 90
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0193.wav which is file number 91
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0061.wav which is file number 92
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0229.wav which is file number 93
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0139.wav which is file number 94
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0054.wav which is file number 95
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0170.wav which is file number 96
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0177.wav which is file number 97
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0021.wav which is file number 98
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0028.wav which is file number 99
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0142.wav which is file number 100
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0179.wav which is file number 101
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0013.wav which is file number 102
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0105.wav which is file number 103
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0082.wav which is file number 104
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0102.wav which is file number 105
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0053.wav which is file number 106
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0066.wav which is file number 107
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0085.wav which is file number 108
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0215.wav which is file number 109
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0131.wav which is file number 110
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0154.wav which is file number 111
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0166.wav which is file number 112
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0153.wav which is file number 113
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0238.wav which is file number 114
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0014.wav which is file number 115
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0077.wav which is file number 116
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0203.wav which is file number 117
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0002.wav which is file number 118
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0185.wav which is file number 119
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0126.wav which is file number 120
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0045.wav which is file number 121
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0070.wav which is file number 122
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0244.wav which is file number 123
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0039.wav which is file number 124
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0128.wav which is file number 125
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0093.wav which is file number 126
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0130.wav which is file number 127
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0204.wav which is file number 128
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0236.wav which is file number 129
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0161.wav which is file number 130
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0227.wav which is file number 131
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0042.wav which is file number 132
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0012.wav which is file number 133
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0231.wav which is file number 134
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0226.wav which is file number 135
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0114.wav which is file number 136
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0079.wav which is file number 137
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0094.wav which is file number 138
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0182.wav which is file number 139
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0068.wav which is file number 140
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0243.wav which is file number 141
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0137.wav which is file number 142
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0220.wav which is file number 143
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0005.wav which is file number 144
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0069.wav which is file number 145
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0202.wav which is file number 146
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0144.wav which is file number 147
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0171.wav which is file number 148
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0192.wav which is file number 149
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0138.wav which is file number 150
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0031.wav which is file number 151
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0221.wav which is file number 152
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0176.wav which is file number 153
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0052.wav which is file number 154
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0178.wav which is file number 155
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0020.wav which is file number 156
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0036.wav which is file number 157
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0136.wav which is file number 158
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0083.wav which is file number 159
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0067.wav which is file number 160
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0027.wav which is file number 161
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0228.wav which is file number 162
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0055.wav which is file number 163
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0084.wav which is file number 164
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0143.wav which is file number 165
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0103.wav which is file number 166
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0115.wav which is file number 167
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0213.wav which is file number 168
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0029.wav which is file number 169
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0104.wav which is file number 170
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0214.wav which is file number 171
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0167.wav which is file number 172
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0071.wav which is file number 173
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0043.wav which is file number 174
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0078.wav which is file number 175
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0245.wav which is file number 176
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0038.wav which is file number 177
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0095.wav which is file number 178
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0049.wav which is file number 179
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0160.wav which is file number 180
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0098.wav which is file number 181
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0112.wav which is file number 182
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0118.wav which is file number 183
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0164.wav which is file number 184
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0206.wav which is file number 185
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0184.wav which is file number 186
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0111.wav which is file number 187
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0040.wav which is file number 188
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0129.wav which is file number 189
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0183.wav which is file number 190
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0152.wav which is file number 191
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0091.wav which is file number 192
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0127.wav which is file number 193
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0044.wav which is file number 194
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0032.wav which is file number 195
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0230.wav which is file number 196
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0035.wav which is file number 197
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0239.wav which is file number 198
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0004.wav which is file number 199
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0116.wav which is file number 200
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0237.wav which is file number 201
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0201.wav which is file number 202
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0120.wav which is file number 203
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0155.wav which is file number 204
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0158.wav which is file number 205
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0151.wav which is file number 206
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0180.wav which is file number 207
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0189.wav which is file number 208
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0140.wav which is file number 209
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0075.wav which is file number 210
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0233.wav which is file number 211
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0234.wav which is file number 212
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0011.wav which is file number 213
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0250.wav which is file number 214
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0191.wav which is file number 215
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0208.wav which is file number 216
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0196.wav which is file number 217
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0241.wav which is file number 218
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0132.wav which is file number 219
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0225.wav which is file number 220
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0064.wav which is file number 221
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0147.wav which is file number 222
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0135.wav which is file number 223
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0172.wav which is file number 224
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0156.wav which is file number 225
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0056.wav which is file number 226
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0096.wav which is file number 227
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0123.wav which is file number 228
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0016.wav which is file number 229
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0198.wav which is file number 230
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0149.wav which is file number 231
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0163.wav which is file number 232
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0222.wav which is file number 233
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0246.wav which is file number 234
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0248.wav which is file number 235
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0009.wav which is file number 236
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0047.wav which is file number 237
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0072.wav which is file number 238
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0109.wav which is file number 239
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0080.wav which is file number 240
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0240.wav which is file number 241
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0186.wav which is file number 242
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0008.wav which is file number 243
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0188.wav which is file number 244
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0249.wav which is file number 245
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0159.wav which is file number 246
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0247.wav which is file number 247
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0157.wav which is file number 248
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0074.wav which is file number 249
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0162.wav which is file number 250
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0073.wav which is file number 251
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0089.wav which is file number 252
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0100.wav which is file number 253
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0217.wav which is file number 254
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0107.wav which is file number 255
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0232.wav which is file number 256
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0181.wav which is file number 257
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0058.wav which is file number 258
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0175.wav which is file number 259
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0051.wav which is file number 260
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0122.wav which is file number 261
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0173.wav which is file number 262
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0097.wav which is file number 263
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0081.wav which is file number 264
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0197.wav which is file number 265
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0106.wav which is file number 266
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0108.wav which is file number 267
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0174.wav which is file number 268
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0165.wav which is file number 269
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0216.wav which is file number 270
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0110.wav which is file number 271
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0146.wav which is file number 272
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0099.wav which is file number 273
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0200.wav which is file number 274
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0218.wav which is file number 275
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0025.wav which is file number 276
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0034.wav which is file number 277
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0050.wav which is file number 278
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0041.wav which is file number 279
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0090.wav which is file number 280
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0207.wav which is file number 281
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0059.wav which is file number 282
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0101.wav which is file number 283
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0086.wav which is file number 284
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0048.wav which is file number 285
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0057.wav which is file number 286
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0119.wav which is file number 287
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0088.wav which is file number 288
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0148.wav which is file number 289
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0141.wav which is file number 290
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0223.wav which is file number 291
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0065.wav which is file number 292
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0010.wav which is file number 293
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0133.wav which is file number 294
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0134.wav which is file number 295
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0190.wav which is file number 296
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0062.wav which is file number 297
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0019.wav which is file number 298
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F04/Session2/wav_arrayMic/0224.wav which is file number 299
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0118.wav which is file number 300
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0063.wav which is file number 301
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0032.wav which is file number 302
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0047.wav which is file number 303
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0191.wav which is file number 304
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0107.wav which is file number 305
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0023.wav which is file number 306
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0007.wav which is file number 307
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0123.wav which is file number 308
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0135.wav which is file number 309
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0058.wav which is file number 310
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0009.wav which is file number 311
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0016.wav which is file number 312
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0048.wav which is file number 313
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0209.wav which is file number 314
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/F/F03/Session3/wav_headMic/0197.wav which is file number 315
# ...
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0084.wav which is file number 3569
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0377.wav which is file number 3570
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0253.wav which is file number 3571
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0510.wav which is file number 3572
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0228.wav which is file number 3573
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0281.wav which is file number 3574
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0405.wav which is file number 3575
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0027.wav which is file number 3576
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0132.wav which is file number 3577
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0149.wav which is file number 3578
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0109.wav which is file number 3579
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0262.wav which is file number 3580
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0470.wav which is file number 3581
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0636.wav which is file number 3582
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0402.wav which is file number 3583
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0268.wav which is file number 3584
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0446.wav which is file number 3585
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0257.wav which is file number 3586
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0308.wav which is file number 3587
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0016.wav which is file number 3588
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0603.wav which is file number 3589
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0225.wav which is file number 3590
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0631.wav which is file number 3591
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0196.wav which is file number 3592
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0638.wav which is file number 3593
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0582.wav which is file number 3594
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0453.wav which is file number 3595
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0325.wav which is file number 3596
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0493.wav which is file number 3597
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0023.wav which is file number 3598
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0494.wav which is file number 3599
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0098.wav which is file number 3600
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0116.wav which is file number 3601
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0570.wav which is file number 3602
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0346.wav which is file number 3603
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0333.wav which is file number 3604
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0485.wav which is file number 3605
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0210.wav which is file number 3606
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0219.wav which is file number 3607
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0265.wav which is file number 3608
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0439.wav which is file number 3609
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0381.wav which is file number 3610
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0322.wav which is file number 3611
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0445.wav which is file number 3612
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0310.wav which is file number 3613
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0466.wav which is file number 3614
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0539.wav which is file number 3615
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0468.wav which is file number 3616
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0612.wav which is file number 3617
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0299.wav which is file number 3618
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0246.wav which is file number 3619
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0335.wav which is file number 3620
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0072.wav which is file number 3621
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0022.wav which is file number 3622
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0211.wav which is file number 3623
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0317.wav which is file number 3624
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0421.wav which is file number 3625
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0180.wav which is file number 3626
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0357.wav which is file number 3627
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0365.wav which is file number 3628
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0009.wav which is file number 3629
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0505.wav which is file number 3630
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0602.wav which is file number 3631
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0218.wav which is file number 3632
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0258.wav which is file number 3633
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0391.wav which is file number 3634
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0347.wav which is file number 3635
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0444.wav which is file number 3636
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0263.wav which is file number 3637
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0050.wav which is file number 3638
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0025.wav which is file number 3639
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0251.wav which is file number 3640
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0436.wav which is file number 3641
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0471.wav which is file number 3642
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0642.wav which is file number 3643
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0515.wav which is file number 3644
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0478.wav which is file number 3645
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0340.wav which is file number 3646
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0216.wav which is file number 3647
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0148.wav which is file number 3648
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0311.wav which is file number 3649
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0467.wav which is file number 3650
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0125.wav which is file number 3651
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0073.wav which is file number 3652
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0291.wav which is file number 3653
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0543.wav which is file number 3654
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0001.wav which is file number 3655
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0621.wav which is file number 3656
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0544.wav which is file number 3657
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0318.wav which is file number 3658
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0240.wav which is file number 3659
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0552.wav which is file number 3660
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0249.wav which is file number 3661
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0033.wav which is file number 3662
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0578.wav which is file number 3663
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0415.wav which is file number 3664
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0119.wav which is file number 3665
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0429.wav which is file number 3666
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0380.wav which is file number 3667
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0503.wav which is file number 3668
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0455.wav which is file number 3669
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0200.wav which is file number 3670
# Written to json for file /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO/MC/MC04/Session1/wav_arrayMic/0117.wav which is file number 3671

# %%
import os
print(os.listdir('/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/'))
# Out:
# ['0015.wav', 'Embeddings.json', 'train_data.list', 'TORGO', 'MSDM', 'TORGO_Embeddings_Mirella.json', 'random_data2.json', 'Mirella_Runs', '.ipynb_checkpoints', 'TORGO_Cut_Mirella_Embeddings', 'TORGO_Embeddings_Mirella_Cut.json']

# %%
# Specify the file path
file_path = '/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Embeddings_Mirella_Cut.json'

# Get the size of the file in bytes
file_size_bytes = os.path.getsize(file_path)

# Convert the size to gigabytes
file_size_gb = file_size_bytes / (1024 ** 3)

# Print the file size in gigabytes
print(f"The size of the file is: {file_size_gb:.6f} GB")
# Out:
# The size of the file is: 8.345087 GB
