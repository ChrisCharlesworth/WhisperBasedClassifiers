# %%
import json
from google.colab import drive
import librosa
from transformers import WhisperForConditionalGeneration, AutoProcessor
import torch
import torch.nn as nn
import numpy as np
import json
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import f1_score, jaccard_score, matthews_corrcoef, hamming_loss
from sklearn.preprocessing import LabelBinarizer
import os
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import time
from datetime import datetime
# import ijson
from sklearn.metrics import confusion_matrix
import os
import json
import numpy as np
import torch
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
folder_path = os.path.join(parent_dir, "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2")

# List all files in the directory
files = os.listdir(folder_path)

# Filter the list to include only files (excluding subdirectories)
file_count = len([f for f in files if os.path.isfile(os.path.join(folder_path, f))])

print(f'There are {file_count} files in the directory.')
# Out:
# There are 3672 files in the directory.

# %%
# Define the directory containing the JSON files
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
folder_path = os.path.join(parent_dir, "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2")

# Initialize lists to store tensor arrays and class numbers
tensor_arrays = []
class_names = []

# Iterate through each file in the directory
counter = 0
for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        # Open and read the JSON file
        with open(file_path, 'r') as f:
            print(file_path)
            data = json.load(f)

            # Extract numpy array and class number
            numpy_array = np.array(data['numpyArray'])
            class_name = data['className']

            # Convert numpy array to torch tensor
            tensor_array = torch.tensor(numpy_array).float()

            # Append to the lists
            tensor_arrays.append(tensor_array)
            class_names.append(class_name)
        counter = counter + 1
        print(counter)

# tensor_arrays is a list of torch tensors
# class_numbers is a list of class numbers
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1844.json
# 1173
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1845.json
# 1174
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1846.json
# 1175
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1847.json
# 1176
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1848.json
# 1177
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1849.json
# 1178
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1850.json
# 1179
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1851.json
# 1180
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1852.json
# 1181
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1853.json
# 1182
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1854.json
# 1183
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1855.json
# 1184
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1856.json
# 1185
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1857.json
# 1186
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1858.json
# 1187
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1859.json
# 1188
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1860.json
# 1189
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1861.json
# 1190
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1862.json
# 1191
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1863.json
# 1192
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1864.json
# 1193
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1865.json
# 1194
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1866.json
# 1195
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1867.json
# 1196
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1868.json
# 1197
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1869.json
# 1198
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1870.json
# 1199
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1871.json
# 1200
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1872.json
# 1201
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1873.json
# 1202
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1874.json
# 1203
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1875.json
# 1204
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1876.json
# 1205
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1877.json
# 1206
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1878.json
# 1207
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1879.json
# 1208
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1880.json
# 1209
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1881.json
# 1210
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1882.json
# 1211
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1883.json
# 1212
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1884.json
# 1213
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1885.json
# 1214
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1886.json
# 1215
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1887.json
# 1216
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1888.json
# 1217
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1889.json
# 1218
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1890.json
# 1219
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1891.json
# 1220
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1892.json
# 1221
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1893.json
# 1222
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1894.json
# 1223
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1895.json
# 1224
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1896.json
# 1225
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1897.json
# 1226
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1898.json
# 1227
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1899.json
# 1228
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1900.json
# 1229
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1901.json
# 1230
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1902.json
# 1231
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1903.json
# 1232
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1904.json
# 1233
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1905.json
# 1234
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1906.json
# 1235
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1907.json
# 1236
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1908.json
# 1237
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1909.json
# 1238
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1910.json
# 1239
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1911.json
# 1240
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1912.json
# 1241
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1913.json
# 1242
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1914.json
# 1243
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1915.json
# 1244
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1916.json
# 1245
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1917.json
# 1246
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1918.json
# 1247
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1919.json
# 1248
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1920.json
# 1249
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1921.json
# 1250
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1922.json
# 1251
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1923.json
# 1252
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1924.json
# 1253
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1925.json
# 1254
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1926.json
# 1255
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1927.json
# 1256
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1928.json
# 1257
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1929.json
# 1258
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1930.json
# 1259
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1931.json
# 1260
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1932.json
# 1261
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1933.json
# 1262
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1934.json
# 1263
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1935.json
# 1264
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1936.json
# 1265
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1937.json
# 1266
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1938.json
# 1267
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1939.json
# 1268
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1940.json
# 1269
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1941.json
# 1270
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1942.json
# 1271
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1943.json
# 1272
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1944.json
# 1273
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1945.json
# 1274
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1946.json
# 1275
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1947.json
# 1276
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1948.json
# 1277
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1949.json
# 1278
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1950.json
# 1279
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1951.json
# 1280
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1952.json
# 1281
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1953.json
# 1282
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1954.json
# 1283
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1955.json
# 1284
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1956.json
# 1285
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1957.json
# 1286
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1958.json
# 1287
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1959.json
# 1288
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1960.json
# 1289
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1961.json
# 1290
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1962.json
# 1291
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1963.json
# 1292
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1964.json
# 1293
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1965.json
# 1294
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1966.json
# 1295
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1967.json
# 1296
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1968.json
# 1297
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1969.json
# 1298
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1970.json
# 1299
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1971.json
# 1300
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1972.json
# 1301
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1973.json
# 1302
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1974.json
# 1303
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1975.json
# 1304
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1976.json
# 1305
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1977.json
# 1306
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1978.json
# 1307
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1979.json
# 1308
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1980.json
# 1309
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1981.json
# 1310
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1982.json
# 1311
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1983.json
# 1312
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1984.json
# 1313
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1985.json
# 1314
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1986.json
# 1315
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1987.json
# 1316
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1988.json
# 1317
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1989.json
# 1318
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1990.json
# 1319
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1991.json
# 1320
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1992.json
# 1321
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1993.json
# 1322
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1994.json
# 1323
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1995.json
# 1324
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1996.json
# 1325
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1997.json
# 1326
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1998.json
# 1327
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/1999.json
# 1328
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2000.json
# 1329
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2001.json
# 1330
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2002.json
# 1331
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2003.json
# 1332
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2004.json
# 1333
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2005.json
# 1334
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2006.json
# 1335
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2007.json
# 1336
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2008.json
# 1337
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2009.json
# 1338
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2010.json
# 1339
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2011.json
# 1340
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2012.json
# 1341
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2013.json
# 1342
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2014.json
# 1343
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2015.json
# 1344
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2016.json
# 1345
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2017.json
# 1346
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2018.json
# 1347
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2019.json
# 1348
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2020.json
# 1349
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2021.json
# 1350
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2022.json
# 1351
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2023.json
# 1352
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2024.json
# 1353
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2025.json
# 1354
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2026.json
# 1355
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2027.json
# 1356
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2028.json
# 1357
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2029.json
# 1358
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2030.json
# 1359
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2031.json
# 1360
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2032.json
# 1361
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2033.json
# 1362
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2034.json
# 1363
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2035.json
# 1364
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2036.json
# 1365
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2037.json
# 1366
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2038.json
# 1367
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2039.json
# 1368
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2040.json
# 1369
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2041.json
# 1370
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2042.json
# 1371
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2043.json
# 1372
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2044.json
# 1373
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2045.json
# 1374
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2046.json
# 1375
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2047.json
# 1376
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2048.json
# 1377
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2049.json
# 1378
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2050.json
# 1379
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2051.json
# 1380
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2052.json
# 1381
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2053.json
# 1382
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2054.json
# 1383
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2055.json
# 1384
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2056.json
# 1385
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2057.json
# 1386
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2058.json
# 1387
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2059.json
# 1388
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2060.json
# 1389
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2061.json
# 1390
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2062.json
# 1391
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2063.json
# 1392
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2064.json
# 1393
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2065.json
# 1394
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2066.json
# 1395
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2067.json
# 1396
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2068.json
# 1397
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2069.json
# 1398
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2070.json
# 1399
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2071.json
# 1400
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2072.json
# 1401
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2073.json
# 1402
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2074.json
# 1403
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2075.json
# 1404
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2076.json
# 1405
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2077.json
# 1406
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2078.json
# 1407
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2079.json
# 1408
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2080.json
# 1409
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2081.json
# 1410
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2082.json
# 1411
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2083.json
# 1412
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2084.json
# 1413
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2085.json
# 1414
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2086.json
# 1415
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2087.json
# 1416
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2088.json
# 1417
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2089.json
# 1418
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2090.json
# 1419
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2091.json
# 1420
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2092.json
# 1421
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2093.json
# 1422
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2094.json
# 1423
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2095.json
# 1424
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2096.json
# 1425
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2097.json
# 1426
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2098.json
# 1427
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2099.json
# 1428
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2100.json
# 1429
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2101.json
# 1430
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2102.json
# 1431
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2103.json
# 1432
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2104.json
# 1433
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2105.json
# 1434
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2106.json
# 1435
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2107.json
# 1436
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2108.json
# 1437
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2109.json
# 1438
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2110.json
# 1439
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2111.json
# 1440
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2112.json
# 1441
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2113.json
# 1442
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2114.json
# 1443
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2115.json
# 1444
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2116.json
# 1445
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2117.json
# 1446
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2118.json
# 1447
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2119.json
# 1448
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2120.json
# 1449
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2121.json
# 1450
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2122.json
# 1451
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2123.json
# 1452
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2124.json
# 1453
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2125.json
# 1454
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2126.json
# 1455
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2127.json
# 1456
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2128.json
# 1457
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2129.json
# 1458
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2130.json
# 1459
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2131.json
# 1460
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2132.json
# 1461
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2133.json
# 1462
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2134.json
# 1463
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2135.json
# 1464
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2136.json
# 1465
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2137.json
# 1466
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2138.json
# 1467
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2139.json
# 1468
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2140.json
# 1469
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2141.json
# 1470
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2142.json
# 1471
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2143.json
# 1472
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2144.json
# 1473
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2145.json
# 1474
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2146.json
# 1475
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2147.json
# 1476
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2148.json
# 1477
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2149.json
# 1478
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2150.json
# 1479
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2151.json
# 1480
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2152.json
# 1481
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2153.json
# 1482
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2154.json
# 1483
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2155.json
# 1484
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2156.json
# 1485
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2157.json
# 1486
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2158.json
# 1487
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2159.json
# 1488
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2160.json
# 1489
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2161.json
# 1490
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2162.json
# 1491
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2163.json
# 1492
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2164.json
# 1493
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2165.json
# 1494
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2166.json
# 1495
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2167.json
# 1496
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2168.json
# 1497
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2169.json
# 1498
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2170.json
# 1499
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2171.json
# 1500
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2172.json
# 1501
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2173.json
# 1502
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2174.json
# 1503
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2175.json
# 1504
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2176.json
# 1505
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2177.json
# 1506
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2178.json
# 1507
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2179.json
# 1508
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2180.json
# 1509
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2181.json
# 1510
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2182.json
# 1511
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2183.json
# 1512
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2184.json
# 1513
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2185.json
# 1514
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2186.json
# 1515
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2187.json
# 1516
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2188.json
# 1517
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2189.json
# 1518
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2190.json
# 1519
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2191.json
# 1520
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2192.json
# 1521
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2193.json
# 1522
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2194.json
# 1523
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2195.json
# 1524
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2196.json
# 1525
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2197.json
# 1526
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2198.json
# 1527
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2199.json
# 1528
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2200.json
# 1529
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2201.json
# 1530
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2202.json
# 1531
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2203.json
# 1532
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2204.json
# 1533
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2205.json
# 1534
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2206.json
# 1535
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2207.json
# 1536
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2208.json
# 1537
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2209.json
# 1538
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2210.json
# 1539
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2211.json
# 1540
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2212.json
# 1541
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2213.json
# 1542
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2214.json
# 1543
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2215.json
# 1544
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2216.json
# 1545
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2217.json
# 1546
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2218.json
# 1547
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2219.json
# 1548
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2220.json
# 1549
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2221.json
# 1550
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2222.json
# 1551
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2223.json
# 1552
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2224.json
# 1553
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2225.json
# 1554
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2226.json
# 1555
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2227.json
# 1556
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2228.json
# 1557
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2229.json
# 1558
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2230.json
# 1559
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2231.json
# 1560
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2232.json
# 1561
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2233.json
# 1562
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2234.json
# 1563
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2235.json
# 1564
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2236.json
# 1565
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2237.json
# 1566
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2238.json
# 1567
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2239.json
# 1568
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2240.json
# 1569
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2241.json
# 1570
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2242.json
# 1571
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2243.json
# 1572
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2244.json
# 1573
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2245.json
# 1574
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2246.json
# 1575
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2247.json
# 1576
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2248.json
# 1577
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2249.json
# 1578
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2250.json
# 1579
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2251.json
# 1580
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2252.json
# 1581
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2253.json
# 1582
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2254.json
# 1583
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2255.json
# 1584
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2256.json
# 1585
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2257.json
# 1586
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2258.json
# 1587
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2259.json
# 1588
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2260.json
# 1589
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2261.json
# 1590
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2262.json
# 1591
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2263.json
# 1592
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2264.json
# 1593
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2265.json
# 1594
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2266.json
# 1595
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2267.json
# 1596
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2268.json
# 1597
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2269.json
# 1598
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2270.json
# 1599
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2271.json
# 1600
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2272.json
# 1601
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2273.json
# 1602
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2274.json
# 1603
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2275.json
# 1604
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2276.json
# 1605
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2277.json
# 1606
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2278.json
# 1607
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2279.json
# 1608
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2280.json
# 1609
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2281.json
# 1610
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2282.json
# 1611
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2283.json
# 1612
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2284.json
# 1613
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2285.json
# 1614
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2286.json
# 1615
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2287.json
# 1616
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2288.json
# 1617
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2289.json
# 1618
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2290.json
# 1619
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2291.json
# 1620
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2292.json
# 1621
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2293.json
# 1622
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2294.json
# 1623
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2295.json
# 1624
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2296.json
# 1625
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2297.json
# 1626
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2298.json
# 1627
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2299.json
# 1628
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2300.json
# 1629
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2301.json
# 1630
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2302.json
# 1631
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2303.json
# 1632
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/2304.json
# 1633
# ...
# 3517
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/517.json
# 3518
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/518.json
# 3519
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/519.json
# 3520
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/520.json
# 3521
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/521.json
# 3522
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/522.json
# 3523
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/523.json
# 3524
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/524.json
# 3525
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/525.json
# 3526
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/526.json
# 3527
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/527.json
# 3528
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/528.json
# 3529
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/529.json
# 3530
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/530.json
# 3531
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/531.json
# 3532
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/532.json
# 3533
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/533.json
# 3534
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/534.json
# 3535
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/535.json
# 3536
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/536.json
# 3537
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/537.json
# 3538
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/538.json
# 3539
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/539.json
# 3540
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/540.json
# 3541
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/541.json
# 3542
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/542.json
# 3543
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/543.json
# 3544
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/544.json
# 3545
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/545.json
# 3546
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/546.json
# 3547
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/547.json
# 3548
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/548.json
# 3549
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/549.json
# 3550
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/550.json
# 3551
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/551.json
# 3552
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/552.json
# 3553
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/553.json
# 3554
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/554.json
# 3555
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/555.json
# 3556
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/556.json
# 3557
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/557.json
# 3558
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/558.json
# 3559
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/559.json
# 3560
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/560.json
# 3561
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/561.json
# 3562
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/562.json
# 3563
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/563.json
# 3564
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/564.json
# 3565
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/565.json
# 3566
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/566.json
# 3567
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/567.json
# 3568
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/568.json
# 3569
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/569.json
# 3570
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/570.json
# 3571
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/571.json
# 3572
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/572.json
# 3573
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/573.json
# 3574
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/574.json
# 3575
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/575.json
# 3576
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/576.json
# 3577
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/577.json
# 3578
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/578.json
# 3579
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/579.json
# 3580
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/580.json
# 3581
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/581.json
# 3582
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/582.json
# 3583
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/583.json
# 3584
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/584.json
# 3585
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/585.json
# 3586
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/586.json
# 3587
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/587.json
# 3588
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/588.json
# 3589
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/589.json
# 3590
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/590.json
# 3591
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/591.json
# 3592
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/592.json
# 3593
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/593.json
# 3594
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/594.json
# 3595
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/595.json
# 3596
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/596.json
# 3597
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/597.json
# 3598
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/598.json
# 3599
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/599.json
# 3600
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/600.json
# 3601
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/601.json
# 3602
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/602.json
# 3603
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/603.json
# 3604
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/604.json
# 3605
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/605.json
# 3606
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/606.json
# 3607
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/607.json
# 3608
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/608.json
# 3609
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/609.json
# 3610
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/610.json
# 3611
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/611.json
# 3612
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/612.json
# 3613
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/613.json
# 3614
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/614.json
# 3615
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/615.json
# 3616
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/616.json
# 3617
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/617.json
# 3618
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/618.json
# 3619
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/619.json
# 3620
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/620.json
# 3621
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/621.json
# 3622
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/622.json
# 3623
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/623.json
# 3624
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/624.json
# 3625
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/625.json
# 3626
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/626.json
# 3627
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/627.json
# 3628
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/628.json
# 3629
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/629.json
# 3630
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/630.json
# 3631
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/631.json
# 3632
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/632.json
# 3633
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/633.json
# 3634
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/634.json
# 3635
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/635.json
# 3636
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/636.json
# 3637
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/637.json
# 3638
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/638.json
# 3639
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/639.json
# 3640
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/640.json
# 3641
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/641.json
# 3642
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/642.json
# 3643
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/643.json
# 3644
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/644.json
# 3645
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/645.json
# 3646
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/646.json
# 3647
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/647.json
# 3648
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/648.json
# 3649
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/649.json
# 3650
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/650.json
# 3651
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/651.json
# 3652
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/652.json
# 3653
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/653.json
# 3654
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/654.json
# 3655
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/655.json
# 3656
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/656.json
# 3657
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/657.json
# 3658
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/658.json
# 3659
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/659.json
# 3660
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/660.json
# 3661
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/661.json
# 3662
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/662.json
# 3663
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/663.json
# 3664
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/664.json
# 3665
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/665.json
# 3666
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/666.json
# 3667
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/667.json
# 3668
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/668.json
# 3669
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/669.json
# 3670
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/670.json
# 3671
# /content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Normal_Embeddings_New_2/671.json
# 3672

# %%
# # start_time = datetime.now()
# # file.write(f"Start time: {start_time}\n")
# # file.flush()

# # Load your data
# current_dir = os.getcwd()
# parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
# embeddings_path = os.path.join(parent_dir, "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Embeddings_Mirella_Cut_New.json")

# # Local Dataset
# # current_dir = os.getcwd()
# # parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
# # embeddings_path = os.path.join(parent_dir, "Embeddings_5.5Seconds.json")

# # file.write('Opening file to read\n')
# with open(embeddings_path, 'r') as f:
#     data = json.load(f)

# file_names = [entry['fileName'] for entry in data]
# numpy_arrays = [np.array(entry['numpyArray']) for entry in data]
# tensor_arrays = [torch.tensor(arr).float() for arr in numpy_arrays]
# # file.write('File has been read\n')
# # file.flush()
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# class_names = []
# tensor_arrays_balanced = []

# for i, file in enumerate(file_names):
#   if ('MC01' in file or 'FCO1' in file or 'MC04/Session1' in file):
#       class_names.append('Healthy')
#       tensor_arrays_balanced.append(tensor_arrays[i])
#   elif ('F04' in file or 'M03' in file):
#       class_names.append('VeryLow')
#       tensor_arrays_balanced.append(tensor_arrays[i])
#   elif ('M05' in file or 'F03' in file ):
#       class_names.append('Low')
#       tensor_arrays_balanced.append(tensor_arrays[i])
#   elif ('F01' in file or 'M01' in file
#         or 'M02' in file or 'M04' in file):
#       class_names.append('Medium')
#       tensor_arrays_balanced.append(tensor_arrays[i])

# tensor_arrays = tensor_arrays_balanced

unique_class_names = ['Healthy', 'VeryLow', 'Low', 'Medium']
class_to_number = {class_name: i for i, class_name in enumerate(unique_class_names)}
class_numbers = [class_to_number[name] for name in class_names]

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Log the start time
output_file_path = "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/Normal_Runs/gru_output.txt"
with open(output_file_path, 'w') as file:

  start_time = datetime.now()
  file.write(f"Start time: {start_time}\n")
  file.flush()

  if torch.cuda.is_available():
    file.write("RUNNING ON GPU\n")
    file.flush()

  else:
    file.write("Running ON CPU\n")
    file.flush()

  class CustomEmbeddingDataset(Dataset):
      def __init__(self, embeddings, class_numbers):
          self.embeddings = embeddings
          self.class_numbers = class_numbers

      def __len__(self):
          return len(self.embeddings)

      def __getitem__(self, index):
          batch_embeddings = self.embeddings[index]
          batch_class_numbers = self.class_numbers[index]
          tensor_batch_class_numbers = torch.tensor(batch_class_numbers)
          return batch_embeddings, tensor_batch_class_numbers

  class RNN(nn.Module):
      def __init__(self, input_size, hidden_size, num_layers, num_classes):
          super(RNN, self).__init__()
          self.num_layers = num_layers
          self.hidden_size = hidden_size
          self.rnn = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
          self.fc = nn.Linear(hidden_size, num_classes)

      def forward(self, x):
          h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
          out, _ = self.rnn(x, h0)
          out = out[:, -1, :]
          out = self.fc(out)
          return out

  input_size = 1280
  hidden_size = 128
  num_layers = 2
  num_classes = 4
  num_epochs = 100
  batch_size = 4
  initial_learning_rate = 0.01
  patience = 13
  k_folds = 10
  # patience = 2
  # k_folds = 2
  sequence_length = 375

  kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

  dataset = CustomEmbeddingDataset(tensor_arrays, class_numbers)

  fold_results = []
  file.write("TRAINING THE MODEL\n")
  file.flush()
  aggregate_cm = np.zeros((num_classes, num_classes), dtype=int)


  for fold, (train_idx, test_idx) in enumerate(kf.split(dataset)):
      output_string = "FOLD NUMBER " + str(fold + 1) + "\n"
      file.write(output_string)
      file.flush()
      train_subset = Subset(dataset, train_idx)
      test_subset = Subset(dataset, test_idx)

      train_validation_x = [x[0] for x in train_subset]
      train_validation_y = [x[1].item() for x in train_subset]
      x_test = [x[0] for x in test_subset]
      y_test = [x[1].item() for x in test_subset]
      x_train, x_validation, y_train, y_validation = train_test_split(train_validation_x, train_validation_y, test_size=0.1, random_state=42)

      train_data_set = CustomEmbeddingDataset(x_train, y_train)
      validation_data_set = CustomEmbeddingDataset(x_validation, y_validation)
      test_data_set = CustomEmbeddingDataset(x_test, y_test)

      train_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True)
      validation_loader = DataLoader(validation_data_set, batch_size=batch_size, shuffle=False)
      test_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=False)

      model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)
      criterion = nn.CrossEntropyLoss()
      optimizer = optim.Adam(model.parameters(), lr=initial_learning_rate)

      scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=4, min_lr=0.00001)

      best_val_loss = float('inf')
      best_epoch = 0

      for epoch in range(num_epochs):
          model.train()
          total_loss = 0
          for images, labels in train_loader:
              images = images.reshape(-1, sequence_length, input_size).to(device)
              labels = labels.to(device)

              outputs = model(images)
              loss = criterion(outputs, labels)

              optimizer.zero_grad()
              loss.backward()
              optimizer.step()
              total_loss += loss.item()

          model.eval()
          val_loss = 0
          y_true_val, y_pred_val = [], []
          n_correct_val = 0
          n_samples_val = 0
          n_class_correct_val = [0 for _ in range(num_classes)]
          n_class_samples_val = [0 for _ in range(num_classes)]
          with torch.no_grad():
              for images, labels in validation_loader:
                  images = images.reshape(-1, sequence_length, input_size).to(device)
                  labels = labels.to(device)
                  outputs = model(images)
                  loss = criterion(outputs, labels)
                  val_loss += loss.item()

                  _, predicted = torch.max(outputs, 1)
                  y_true_val.extend(labels.cpu().numpy())
                  y_pred_val.extend(predicted.cpu().numpy())

                  n_samples_val += labels.size(0)
                  n_correct_val += (predicted == labels).sum().item()
                  for i in range(len(labels)):
                      label = labels[i].item()
                      pred = predicted[i].item()
                      if label == pred:
                          n_class_correct_val[label] += 1
                      n_class_samples_val[label] += 1

          y_true, y_pred = [], []
          n_correct = 0
          n_samples = 0
          n_class_correct = [0 for _ in range(num_classes)]
          n_class_samples = [0 for _ in range(num_classes)]
          with torch.no_grad():
              for images, labels in test_loader:
                  images = images.reshape(-1, sequence_length, input_size).to(device)
                  labels = labels.to(device)
                  outputs = model(images)
                  _, predicted = torch.max(outputs, 1)
                  y_true.extend(labels.cpu().numpy())
                  y_pred.extend(predicted.cpu().numpy())

                  n_samples += labels.size(0)
                  n_correct += (predicted == labels).sum().item()
                  for i in range(len(labels)):
                      label = labels[i].item()
                      pred = predicted[i].item()
                      if label == pred:
                          n_class_correct[label] += 1
                      n_class_samples[label] += 1

          val_loss /= len(validation_loader)
          acc = 100.0 * n_correct / n_samples
          acc_val = 100.0 * n_correct_val / n_samples_val
          file.write(f"Epoch {epoch+1}, Validation Loss: {val_loss:.4f}, Learning Rate: {optimizer.param_groups[0]['lr']}\n")
          file.write(f"Test Accuracy of the network: {acc} %\n")
          file.write(f"Validation Accuracy of the network: {acc_val} %\n")
          current_time = datetime.now()
          file.write(f"Start time: {current_time}\n")
          file.flush()

          scheduler.step(val_loss)

          if val_loss < best_val_loss:
              best_val_loss = val_loss
              best_epoch = epoch
              torch.save(model.state_dict(), f'GRU_best_model_fold_{fold}.pth')
          elif epoch - best_epoch >= patience:
              file.write(f"Early stopping at epoch {epoch + 1}\n")
              file.flush()
              break

      model.load_state_dict(torch.load(f"GRU_best_model_fold_{fold}.pth"))

      # Evaluation
      model.eval()
      y_true, y_pred = [], []
      n_correct = 0
      n_samples = 0
      n_class_correct = [0 for _ in range(num_classes)]
      n_class_samples = [0 for _ in range(num_classes)]
      with torch.no_grad():
          for images, labels in test_loader:
              images = images.reshape(-1, sequence_length, input_size).to(device)
              labels = labels.to(device)
              outputs = model(images)
              _, predicted = torch.max(outputs, 1)
              y_true.extend(labels.cpu().numpy())
              y_pred.extend(predicted.cpu().numpy())

              n_samples += labels.size(0)
              n_correct += (predicted == labels).sum().item()
              for i in range(len(labels)):
                  label = labels[i].item()
                  pred = predicted[i].item()
                  if label == pred:
                      n_class_correct[label] += 1
                  n_class_samples[label] += 1

          acc = 100.0 * n_correct / n_samples
          file.write(f"Accuracy of the network: {acc} %\n")
          file.flush()

          class_accs = []
          for i in range(num_classes):
              if n_class_samples[i] != 0:
                  current_acc = 100.0 * n_class_correct[i] / n_class_samples[i]
                  class_accs.append(current_acc)
                  file.write(f"Accuracy of {i}: {current_acc} %\n")
                  file.flush()
              else:
                  class_accs.append(0.0)
                  file.write(f"Accuracy of {i}: No samples\n")
                  file.flush()

      f1_micro = f1_score(y_true, y_pred, average='micro')
      f1_macro = f1_score(y_true, y_pred, average='macro')
      f1_weighted = f1_score(y_true, y_pred, average='weighted')
      jaccard_micro = jaccard_score(y_true, y_pred, average='micro')
      jaccard_macro = jaccard_score(y_true, y_pred, average='macro')
      jaccard_weighted = jaccard_score(y_true, y_pred, average='weighted')
      lb = LabelBinarizer()
      y_true_bin = lb.fit_transform(y_true)
      y_pred_bin = lb.transform(y_pred)
      mccs = [matthews_corrcoef(y_true_bin[:, i], y_pred_bin[:, i]) for i in range(len(lb.classes_))]
      average_mcc = sum(mccs) / len(mccs)
      hl = hamming_loss(y_true_bin, y_pred_bin)
      cm = confusion_matrix(y_true, y_pred)
      file.write(f"Fold: {fold}\n")
      file.write(f"Confusion Matrix:\n{cm}\n")
      file.write(f"Accuracy: {acc:.2f}%\n")
      file.write(f"F1 Micro: {f1_micro:.4f}\n")
      file.write(f"F1 Macro: {f1_macro:.4f}\n")
      file.write(f"F1 Weighted: {f1_weighted:.4f}\n")
      file.write(f"Jaccard Micro: {jaccard_micro:.4f}\n")
      file.write(f"Jaccard Macro: {jaccard_macro:.4f}\n")
      file.write(f"Jaccard Weighted: {jaccard_weighted:.4f}\n")
      file.write(f"MCC: {average_mcc:.4f}\n")
      file.write(f"Hamming Loss: {hl:.4f}\n")
      file.flush()

      aggregate_cm += cm

      fold_results.append({
          'fold': fold,
          'accuracy': acc,
          'class_accuracy': class_accs,
          'f1_micro': f1_micro,
          'f1_macro': f1_macro,
          'f1_weighted': f1_weighted,
          'jaccard_micro': jaccard_micro,
          'jaccard_macro': jaccard_macro,
          'jaccard_weighted': jaccard_weighted,
          'mcc': average_mcc,
          'hamming_loss': hl
      })

  # Compute and print the average metrics
  avg_accuracy = sum(result['accuracy'] for result in fold_results) / k_folds
  avg_class_accuracy = [sum(result['class_accuracy'][i] for result in fold_results) / k_folds for i in range(num_classes)]
  avg_f1_micro = sum(result['f1_micro'] for result in fold_results) / k_folds
  avg_f1_macro = sum(result['f1_macro'] for result in fold_results) / k_folds
  avg_f1_weighted = sum(result['f1_weighted'] for result in fold_results) / k_folds
  avg_jaccard_micro = sum(result['jaccard_micro'] for result in fold_results) / k_folds
  avg_jaccard_macro = sum(result['jaccard_macro'] for result in fold_results) / k_folds
  avg_jaccard_weighted = sum(result['jaccard_weighted'] for result in fold_results) / k_folds
  avg_mcc = sum(result['mcc'] for result in fold_results) / k_folds
  avg_hamming_loss = sum(result['hamming_loss'] for result in fold_results) / k_folds

  file.write(f"Average accuracy: {avg_accuracy:.2f}%\n")
  file.flush()
  for i in range(num_classes):
      file.write(f"Average accuracy of {i}: {avg_class_accuracy[i]:.2f}%\n")
  file.write(f"Average F1 Score (Micro): {avg_f1_micro:.4f}\n")
  file.write(f"Average F1 Score (Macro): {avg_f1_macro:.4f}\n")
  file.write(f"Average F1 Score (Weighted): {avg_f1_weighted:.4f}\n")
  file.write(f"Average Jaccard Score (Micro): {avg_jaccard_micro:.4f}\n")
  file.write(f"Average Jaccard Score (Macro): {avg_jaccard_macro:.4f}\n")
  file.write(f"Average Jaccard Score (Weighted): {avg_jaccard_weighted:.4f}\n")
  file.write(f"Average MCC: {avg_mcc:.4f}\n")
  file.write(f"Average Hamming Loss: {avg_hamming_loss:.4f}\n")
  file.write(f"Cumulative Confusion Matrix: {aggregate_cm}\n")
  # Log the end time
  end_time = datetime.now()
  file.write(f"End time: {end_time}\n")

  # Optionally, you can also log the duration
  duration = end_time - start_time
  file.write(f"Duration: {duration}\n")

# %% [markdown]
# LSTM

# %%
# Log the start time
output_file_path = "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/Normal_Runs/lstm_output.txt"
with open(output_file_path, 'w') as file:
    start_time = datetime.now()
    file.write(f"Start time: {start_time}\n")
    file.flush()

    # Load your data
    # current_dir = os.getcwd()
    # parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
    # embeddings_path = os.path.join(parent_dir, "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Embeddings_Mirella_Cut.json")

    # # Local Dataset
    # # current_dir = os.getcwd()
    # # parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
    # # embeddings_path = os.path.join(parent_dir, "Embeddings_5.5Seconds.json")

    # file.write('Opening file to read\n')
    # with open(embeddings_path, 'r') as f:
    #     data = json.load(f)

    # file_names = [entry['fileName'] for entry in data]
    # numpy_arrays = [np.array(entry['numpyArray']) for entry in data]
    # tensor_arrays = [torch.tensor(arr).float() for arr in numpy_arrays]
    # file.write('File has been read\n')
    # file.flush()
    # device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # class_names = []
    # tensor_arrays_balanced = []

    # for i, file_name in enumerate(file_names):
    #     if ('MC01' in file_name or 'FCO1' in file_name or 'MC04/Session2' in file_name):
    #         class_names.append('Healthy')
    #         tensor_arrays_balanced.append(tensor_arrays[i])
    #     elif ('F04' in file_name or 'M03' in file_name):
    #         class_names.append('VeryLow')
    #         tensor_arrays_balanced.append(tensor_arrays[i])
    #     elif ('F01' in file_name or 'M05' in file_name or 'F03/Session2' in file_name or 'F03/Session3' in file_name ):
    #         class_names.append('Low')
    #         tensor_arrays_balanced.append(tensor_arrays[i])
    #     elif ('M01' in file_name or 'M01' in file_name or 'M02' in file_name or 'M04' in file_name):
    #         class_names.append('Medium')
    #         tensor_arrays_balanced.append(tensor_arrays[i])

    # tensor_arrays = tensor_arrays_balanced

    # unique_class_names = ['Healthy', 'Low', 'VeryLow', 'Medium']
    # class_to_number = {class_name: i for i, class_name in enumerate(unique_class_names)}
    # class_numbers = [class_to_number[name] for name in class_names]

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    if torch.cuda.is_available():
        file.write("RUNNING ON GPU\n")
        file.flush()

    else:
        file.write("Running ON CPU\n")
        file.flush()

    class CustomEmbeddingDataset(Dataset):
        def __init__(self, embeddings, class_numbers):
            self.embeddings = embeddings
            self.class_numbers = class_numbers

        def __len__(self):
            return len(self.embeddings)

        def __getitem__(self, index):
            batch_embeddings = self.embeddings[index]
            batch_class_numbers = self.class_numbers[index]
            tensor_batch_class_numbers = torch.tensor(batch_class_numbers)
            return batch_embeddings, tensor_batch_class_numbers

    class RNN(nn.Module):
        def __init__(self, input_size, hidden_size, num_layers, num_classes):
            super(RNN, self).__init__()
            self.num_layers = num_layers
            self.hidden_size = hidden_size
            self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
            self.fc = nn.Linear(hidden_size, num_classes)

        def forward(self, x):
            # Set initial hidden states (and cell states for LSTM)
            h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

            # FOR LSTMs they also need an initial cell state so you need to add this as well
            c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
            out, _ = self.lstm(x, (h0,c0))
            # out: tensor of shape (batch_size, seq_length, hidden_size)
            # out: (n, 28, 128)
            # Decode the hidden state of the last time step
            out = out[:, -1, :]
            # out: (n, 128)
            out = self.fc(out)
            # out: (n, 10)
            return out

    input_size = 1280
    hidden_size = 128
    num_layers = 2
    num_classes = 4
    num_epochs = 100
    batch_size = 4
    initial_learning_rate = 0.01
    patience = 13
    k_folds = 10
    # patience = 2
    # k_folds = 2
    sequence_length = 375

    kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

    dataset = CustomEmbeddingDataset(tensor_arrays, class_numbers)

    fold_results = []
    file.write("TRAINING THE MODEL\n")
    file.flush()
    aggregate_cm = np.zeros((num_classes, num_classes), dtype=int)


    for fold, (train_idx, test_idx) in enumerate(kf.split(dataset)):
        output_string = "FOLD NUMBER " + str(fold + 1) + "\n"
        file.write(output_string)
        file.flush()
        train_subset = Subset(dataset, train_idx)
        test_subset = Subset(dataset, test_idx)

        train_validation_x = [x[0] for x in train_subset]
        train_validation_y = [x[1].item() for x in train_subset]
        x_test = [x[0] for x in test_subset]
        y_test = [x[1].item() for x in test_subset]
        x_train, x_validation, y_train, y_validation = train_test_split(train_validation_x, train_validation_y, test_size=0.1, random_state=42)

        train_data_set = CustomEmbeddingDataset(x_train, y_train)
        validation_data_set = CustomEmbeddingDataset(x_validation, y_validation)
        test_data_set = CustomEmbeddingDataset(x_test, y_test)

        train_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True)
        validation_loader = DataLoader(validation_data_set, batch_size=batch_size, shuffle=False)
        test_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=False)

        model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=initial_learning_rate)

        scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=4, min_lr=0.00001)

        best_val_loss = float('inf')
        best_epoch = 0

        for epoch in range(num_epochs):
            model.train()
            total_loss = 0
            for images, labels in train_loader:
                images = images.reshape(-1, sequence_length, input_size).to(device)
                labels = labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()

            model.eval()
            val_loss = 0
            y_true_val, y_pred_val = [], []
            n_correct_val = 0
            n_samples_val = 0
            n_class_correct_val = [0 for _ in range(num_classes)]
            n_class_samples_val = [0 for _ in range(num_classes)]
            with torch.no_grad():
                for images, labels in validation_loader:
                    images = images.reshape(-1, sequence_length, input_size).to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    val_loss += loss.item()

                    _, predicted = torch.max(outputs, 1)
                    y_true_val.extend(labels.cpu().numpy())
                    y_pred_val.extend(predicted.cpu().numpy())

                    n_samples_val += labels.size(0)
                    n_correct_val += (predicted == labels).sum().item()
                    for i in range(len(labels)):
                        label = labels[i].item()
                        pred = predicted[i].item()
                        if label == pred:
                            n_class_correct_val[label] += 1
                        n_class_samples_val[label] += 1

            y_true, y_pred = [], []
            n_correct = 0
            n_samples = 0
            n_class_correct = [0 for _ in range(num_classes)]
            n_class_samples = [0 for _ in range(num_classes)]
            with torch.no_grad():
                for images, labels in test_loader:
                    images = images.reshape(-1, sequence_length, input_size).to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    _, predicted = torch.max(outputs, 1)
                    y_true.extend(labels.cpu().numpy())
                    y_pred.extend(predicted.cpu().numpy())

                    n_samples += labels.size(0)
                    n_correct += (predicted == labels).sum().item()
                    for i in range(len(labels)):
                        label = labels[i].item()
                        pred = predicted[i].item()
                        if label == pred:
                            n_class_correct[label] += 1
                        n_class_samples[label] += 1

            val_loss /= len(validation_loader)
            acc = 100.0 * n_correct / n_samples
            acc_val = 100.0 * n_correct_val / n_samples_val
            file.write(f"Epoch {epoch+1}, Validation Loss: {val_loss:.4f}, Learning Rate: {optimizer.param_groups[0]['lr']}\n")
            file.write(f"Test Accuracy of the network: {acc} %\n")
            file.write(f"Validation Accuracy of the network: {acc_val} %\n")
            current_time = datetime.now()
            file.write(f"Start time: {current_time}\n")
            file.flush()

            scheduler.step(val_loss)

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_epoch = epoch
                torch.save(model.state_dict(), f'LSTM_best_model_fold_{fold}.pth')
            elif epoch - best_epoch >= patience:
                file.write(f"Early stopping at epoch {epoch + 1}\n")
                file.flush()
                break

        model.load_state_dict(torch.load(f"LSTM_best_model_fold_{fold}.pth"))

        # Evaluation
        model.eval()
        y_true, y_pred = [], []
        n_correct = 0
        n_samples = 0
        n_class_correct = [0 for _ in range(num_classes)]
        n_class_samples = [0 for _ in range(num_classes)]
        with torch.no_grad():
            for images, labels in test_loader:
                images = images.reshape(-1, sequence_length, input_size).to(device)
                labels = labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs, 1)
                y_true.extend(labels.cpu().numpy())
                y_pred.extend(predicted.cpu().numpy())

                n_samples += labels.size(0)
                n_correct += (predicted == labels).sum().item()
                for i in range(len(labels)):
                    label = labels[i].item()
                    pred = predicted[i].item()
                    if label == pred:
                        n_class_correct[label] += 1
                    n_class_samples[label] += 1

            acc = 100.0 * n_correct / n_samples
            file.write(f"Accuracy of the network: {acc} %\n")
            file.flush()

            class_accs = []
            for i in range(num_classes):
                if n_class_samples[i] != 0:
                    current_acc = 100.0 * n_class_correct[i] / n_class_samples[i]
                    class_accs.append(current_acc)
                    file.write(f"Accuracy of {i}: {current_acc} %\n")
                    file.flush()
                else:
                    class_accs.append(0.0)
                    file.write(f"Accuracy of {i}: No samples\n")
                    file.flush()

        f1_micro = f1_score(y_true, y_pred, average='micro')
        f1_macro = f1_score(y_true, y_pred, average='macro')
        f1_weighted = f1_score(y_true, y_pred, average='weighted')
        jaccard_micro = jaccard_score(y_true, y_pred, average='micro')
        jaccard_macro = jaccard_score(y_true, y_pred, average='macro')
        jaccard_weighted = jaccard_score(y_true, y_pred, average='weighted')
        lb = LabelBinarizer()
        y_true_bin = lb.fit_transform(y_true)
        y_pred_bin = lb.transform(y_pred)
        mccs = [matthews_corrcoef(y_true_bin[:, i], y_pred_bin[:, i]) for i in range(len(lb.classes_))]
        average_mcc = sum(mccs) / len(mccs)
        hl = hamming_loss(y_true_bin, y_pred_bin)
        cm = confusion_matrix(y_true, y_pred)
        file.write(f"Fold: {fold}\n")
        file.write(f"Confusion Matrix:\n{cm}\n")
        file.write(f"Accuracy: {acc:.2f}%\n")
        file.write(f"F1 Micro: {f1_micro:.4f}\n")
        file.write(f"F1 Macro: {f1_macro:.4f}\n")
        file.write(f"F1 Weighted: {f1_weighted:.4f}\n")
        file.write(f"Jaccard Micro: {jaccard_micro:.4f}\n")
        file.write(f"Jaccard Macro: {jaccard_macro:.4f}\n")
        file.write(f"Jaccard Weighted: {jaccard_weighted:.4f}\n")
        file.write(f"MCC: {average_mcc:.4f}\n")
        file.write(f"Hamming Loss: {hl:.4f}\n")
        file.flush()

        aggregate_cm += cm

        fold_results.append({
            'fold': fold,
            'accuracy': acc,
            'class_accuracy': class_accs,
            'f1_micro': f1_micro,
            'f1_macro': f1_macro,
            'f1_weighted': f1_weighted,
            'jaccard_micro': jaccard_micro,
            'jaccard_macro': jaccard_macro,
            'jaccard_weighted': jaccard_weighted,
            'mcc': average_mcc,
            'hamming_loss': hl
        })

    # Compute and print the average metrics
    avg_accuracy = sum(result['accuracy'] for result in fold_results) / k_folds
    avg_class_accuracy = [sum(result['class_accuracy'][i] for result in fold_results) / k_folds for i in range(num_classes)]
    avg_f1_micro = sum(result['f1_micro'] for result in fold_results) / k_folds
    avg_f1_macro = sum(result['f1_macro'] for result in fold_results) / k_folds
    avg_f1_weighted = sum(result['f1_weighted'] for result in fold_results) / k_folds
    avg_jaccard_micro = sum(result['jaccard_micro'] for result in fold_results) / k_folds
    avg_jaccard_macro = sum(result['jaccard_macro'] for result in fold_results) / k_folds
    avg_jaccard_weighted = sum(result['jaccard_weighted'] for result in fold_results) / k_folds
    avg_mcc = sum(result['mcc'] for result in fold_results) / k_folds
    avg_hamming_loss = sum(result['hamming_loss'] for result in fold_results) / k_folds

    file.write(f"Average accuracy: {avg_accuracy:.2f}%\n")
    file.flush()
    for i in range(num_classes):
        file.write(f"Average accuracy of {i}: {avg_class_accuracy[i]:.2f}%\n")
    file.write(f"Average F1 Score (Micro): {avg_f1_micro:.4f}\n")
    file.write(f"Average F1 Score (Macro): {avg_f1_macro:.4f}\n")
    file.write(f"Average F1 Score (Weighted): {avg_f1_weighted:.4f}\n")
    file.write(f"Average Jaccard Score (Micro): {avg_jaccard_micro:.4f}\n")
    file.write(f"Average Jaccard Score (Macro): {avg_jaccard_macro:.4f}\n")
    file.write(f"Average Jaccard Score (Weighted): {avg_jaccard_weighted:.4f}\n")
    file.write(f"Average MCC: {avg_mcc:.4f}\n")
    file.write(f"Average Hamming Loss: {avg_hamming_loss:.4f}\n")
    file.write(f"Cumulative Confusion Matrix: {aggregate_cm}\n")
    # Log the end time
    end_time = datetime.now()
    file.write(f"End time: {end_time}\n")

    # Optionally, you can also log the duration
    duration = end_time - start_time
    file.write(f"Duration: {duration}\n")

# %% [markdown]
# RNN

# %%
# Log the start time
output_file_path = "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/Normal_Runs/rnn_output.txt"
with open(output_file_path, 'w') as file:
    start_time = datetime.now()
    file.write(f"Start time: {start_time}\n")
    file.flush()

    # Load your data
    # current_dir = os.getcwd()
    # parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
    # embeddings_path = os.path.join(parent_dir, "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Embeddings_Mirella_Cut.json")

    # # Local Dataset
    # # current_dir = os.getcwd()
    # # parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
    # # embeddings_path = os.path.join(parent_dir, "Embeddings_5.5Seconds.json")

    # file.write('Opening file to read\n')
    # with open(embeddings_path, 'r') as f:
    #     data = json.load(f)

    # file_names = [entry['fileName'] for entry in data]
    # numpy_arrays = [np.array(entry['numpyArray']) for entry in data]
    # tensor_arrays = [torch.tensor(arr).float() for arr in numpy_arrays]
    # file.write('File has been read\n')
    # file.flush()
    # device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # class_names = []
    # tensor_arrays_balanced = []

    # for i, file_name in enumerate(file_names):
    #     if ('MC01' in file_name or 'FCO1' in file_name or 'MC04/Session2' in file_name):
    #         class_names.append('Healthy')
    #         tensor_arrays_balanced.append(tensor_arrays[i])
    #     elif ('F04' in file_name or 'M03' in file_name):
    #         class_names.append('VeryLow')
    #         tensor_arrays_balanced.append(tensor_arrays[i])
    #     elif ('F01' in file_name or 'M05' in file_name or 'F03/Session2' in file_name or 'F03/Session3' in file_name ):
    #         class_names.append('Low')
    #         tensor_arrays_balanced.append(tensor_arrays[i])
    #     elif ('M01' in file_name or 'M01' in file_name or 'M02' in file_name or 'M04' in file_name):
    #         class_names.append('Medium')
    #         tensor_arrays_balanced.append(tensor_arrays[i])

    # tensor_arrays = tensor_arrays_balanced

    # unique_class_names = ['Healthy', 'Low', 'VeryLow', 'Medium']
    # class_to_number = {class_name: i for i, class_name in enumerate(unique_class_names)}
    # class_numbers = [class_to_number[name] for name in class_names]

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    if torch.cuda.is_available():
        file.write("RUNNING ON GPU\n")
        file.flush()

    else:
        file.write("Running ON CPU\n")
        file.flush()

    class CustomEmbeddingDataset(Dataset):
        def __init__(self, embeddings, class_numbers):
            self.embeddings = embeddings
            self.class_numbers = class_numbers

        def __len__(self):
            return len(self.embeddings)

        def __getitem__(self, index):
            batch_embeddings = self.embeddings[index]
            batch_class_numbers = self.class_numbers[index]
            tensor_batch_class_numbers = torch.tensor(batch_class_numbers)
            return batch_embeddings, tensor_batch_class_numbers

    class RNN(nn.Module):
        def __init__(self, input_size, hidden_size, num_layers, num_classes):
            super(RNN, self).__init__()
            self.num_layers = num_layers
            self.hidden_size = hidden_size

            self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
            self.fc = nn.Linear(hidden_size, num_classes)

        def forward(self, x):
            h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

            # FOR LSTMs they also need an initial cell state so you need to add this as well
            c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
            # Forward propagate RNN
            out, _ = self.rnn(x, h0)
            out = out[:, -1, :]
            out = self.fc(out)
            return out

    input_size = 1280
    hidden_size = 128
    num_layers = 2
    num_classes = 4
    num_epochs = 100
    batch_size = 4
    initial_learning_rate = 0.01
    patience = 13
    k_folds = 10
    # patience = 2
    # k_folds = 2
    sequence_length = 375

    kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

    dataset = CustomEmbeddingDataset(tensor_arrays, class_numbers)

    fold_results = []
    file.write("TRAINING THE MODEL\n")
    file.flush()
    aggregate_cm = np.zeros((num_classes, num_classes), dtype=int)


    for fold, (train_idx, test_idx) in enumerate(kf.split(dataset)):
        output_string = "FOLD NUMBER " + str(fold + 1) + "\n"
        file.write(output_string)
        file.flush()
        train_subset = Subset(dataset, train_idx)
        test_subset = Subset(dataset, test_idx)

        train_validation_x = [x[0] for x in train_subset]
        train_validation_y = [x[1].item() for x in train_subset]
        x_test = [x[0] for x in test_subset]
        y_test = [x[1].item() for x in test_subset]
        x_train, x_validation, y_train, y_validation = train_test_split(train_validation_x, train_validation_y, test_size=0.1, random_state=42)

        train_data_set = CustomEmbeddingDataset(x_train, y_train)
        validation_data_set = CustomEmbeddingDataset(x_validation, y_validation)
        test_data_set = CustomEmbeddingDataset(x_test, y_test)

        train_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True)
        validation_loader = DataLoader(validation_data_set, batch_size=batch_size, shuffle=False)
        test_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=False)

        model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=initial_learning_rate)

        scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=4, min_lr=0.00001)

        best_val_loss = float('inf')
        best_epoch = 0

        for epoch in range(num_epochs):
            model.train()
            total_loss = 0
            for images, labels in train_loader:
                images = images.reshape(-1, sequence_length, input_size).to(device)
                labels = labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()

            model.eval()
            val_loss = 0
            y_true_val, y_pred_val = [], []
            n_correct_val = 0
            n_samples_val = 0
            n_class_correct_val = [0 for _ in range(num_classes)]
            n_class_samples_val = [0 for _ in range(num_classes)]
            with torch.no_grad():
                for images, labels in validation_loader:
                    images = images.reshape(-1, sequence_length, input_size).to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    val_loss += loss.item()

                    _, predicted = torch.max(outputs, 1)
                    y_true_val.extend(labels.cpu().numpy())
                    y_pred_val.extend(predicted.cpu().numpy())

                    n_samples_val += labels.size(0)
                    n_correct_val += (predicted == labels).sum().item()
                    for i in range(len(labels)):
                        label = labels[i].item()
                        pred = predicted[i].item()
                        if label == pred:
                            n_class_correct_val[label] += 1
                        n_class_samples_val[label] += 1

            y_true, y_pred = [], []
            n_correct = 0
            n_samples = 0
            n_class_correct = [0 for _ in range(num_classes)]
            n_class_samples = [0 for _ in range(num_classes)]
            with torch.no_grad():
                for images, labels in test_loader:
                    images = images.reshape(-1, sequence_length, input_size).to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    _, predicted = torch.max(outputs, 1)
                    y_true.extend(labels.cpu().numpy())
                    y_pred.extend(predicted.cpu().numpy())

                    n_samples += labels.size(0)
                    n_correct += (predicted == labels).sum().item()
                    for i in range(len(labels)):
                        label = labels[i].item()
                        pred = predicted[i].item()
                        if label == pred:
                            n_class_correct[label] += 1
                        n_class_samples[label] += 1

            val_loss /= len(validation_loader)
            acc = 100.0 * n_correct / n_samples
            acc_val = 100.0 * n_correct_val / n_samples_val
            file.write(f"Epoch {epoch+1}, Validation Loss: {val_loss:.4f}, Learning Rate: {optimizer.param_groups[0]['lr']}\n")
            file.write(f"Test Accuracy of the network: {acc} %\n")
            file.write(f"Validation Accuracy of the network: {acc_val} %\n")
            current_time = datetime.now()
            file.write(f"Start time: {current_time}\n")
            file.flush()

            scheduler.step(val_loss)

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_epoch = epoch
                torch.save(model.state_dict(), f'RNN_best_model_fold_{fold}.pth')
            elif epoch - best_epoch >= patience:
                file.write(f"Early stopping at epoch {epoch + 1}\n")
                file.flush()
                break

        model.load_state_dict(torch.load(f"RNN_best_model_fold_{fold}.pth"))

        # Evaluation
        model.eval()
        y_true, y_pred = [], []
        n_correct = 0
        n_samples = 0
        n_class_correct = [0 for _ in range(num_classes)]
        n_class_samples = [0 for _ in range(num_classes)]
        with torch.no_grad():
            for images, labels in test_loader:
                images = images.reshape(-1, sequence_length, input_size).to(device)
                labels = labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs, 1)
                y_true.extend(labels.cpu().numpy())
                y_pred.extend(predicted.cpu().numpy())

                n_samples += labels.size(0)
                n_correct += (predicted == labels).sum().item()
                for i in range(len(labels)):
                    label = labels[i].item()
                    pred = predicted[i].item()
                    if label == pred:
                        n_class_correct[label] += 1
                    n_class_samples[label] += 1

            acc = 100.0 * n_correct / n_samples
            file.write(f"Accuracy of the network: {acc} %\n")
            file.flush()

            class_accs = []
            for i in range(num_classes):
                if n_class_samples[i] != 0:
                    current_acc = 100.0 * n_class_correct[i] / n_class_samples[i]
                    class_accs.append(current_acc)
                    file.write(f"Accuracy of {i}: {current_acc} %\n")
                    file.flush()
                else:
                    class_accs.append(0.0)
                    file.write(f"Accuracy of {i}: No samples\n")
                    file.flush()

        f1_micro = f1_score(y_true, y_pred, average='micro')
        f1_macro = f1_score(y_true, y_pred, average='macro')
        f1_weighted = f1_score(y_true, y_pred, average='weighted')
        jaccard_micro = jaccard_score(y_true, y_pred, average='micro')
        jaccard_macro = jaccard_score(y_true, y_pred, average='macro')
        jaccard_weighted = jaccard_score(y_true, y_pred, average='weighted')
        lb = LabelBinarizer()
        y_true_bin = lb.fit_transform(y_true)
        y_pred_bin = lb.transform(y_pred)
        mccs = [matthews_corrcoef(y_true_bin[:, i], y_pred_bin[:, i]) for i in range(len(lb.classes_))]
        average_mcc = sum(mccs) / len(mccs)
        hl = hamming_loss(y_true_bin, y_pred_bin)
        cm = confusion_matrix(y_true, y_pred)
        file.write(f"Fold: {fold}\n")
        file.write(f"Confusion Matrix:\n{cm}\n")
        file.write(f"Accuracy: {acc:.2f}%\n")
        file.write(f"F1 Micro: {f1_micro:.4f}\n")
        file.write(f"F1 Macro: {f1_macro:.4f}\n")
        file.write(f"F1 Weighted: {f1_weighted:.4f}\n")
        file.write(f"Jaccard Micro: {jaccard_micro:.4f}\n")
        file.write(f"Jaccard Macro: {jaccard_macro:.4f}\n")
        file.write(f"Jaccard Weighted: {jaccard_weighted:.4f}\n")
        file.write(f"MCC: {average_mcc:.4f}\n")
        file.write(f"Hamming Loss: {hl:.4f}\n")
        file.flush()

        aggregate_cm += cm

        fold_results.append({
            'fold': fold,
            'accuracy': acc,
            'class_accuracy': class_accs,
            'f1_micro': f1_micro,
            'f1_macro': f1_macro,
            'f1_weighted': f1_weighted,
            'jaccard_micro': jaccard_micro,
            'jaccard_macro': jaccard_macro,
            'jaccard_weighted': jaccard_weighted,
            'mcc': average_mcc,
            'hamming_loss': hl
        })

    # Compute and print the average metrics
    avg_accuracy = sum(result['accuracy'] for result in fold_results) / k_folds
    avg_class_accuracy = [sum(result['class_accuracy'][i] for result in fold_results) / k_folds for i in range(num_classes)]
    avg_f1_micro = sum(result['f1_micro'] for result in fold_results) / k_folds
    avg_f1_macro = sum(result['f1_macro'] for result in fold_results) / k_folds
    avg_f1_weighted = sum(result['f1_weighted'] for result in fold_results) / k_folds
    avg_jaccard_micro = sum(result['jaccard_micro'] for result in fold_results) / k_folds
    avg_jaccard_macro = sum(result['jaccard_macro'] for result in fold_results) / k_folds
    avg_jaccard_weighted = sum(result['jaccard_weighted'] for result in fold_results) / k_folds
    avg_mcc = sum(result['mcc'] for result in fold_results) / k_folds
    avg_hamming_loss = sum(result['hamming_loss'] for result in fold_results) / k_folds

    file.write(f"Average accuracy: {avg_accuracy:.2f}%\n")
    file.flush()
    for i in range(num_classes):
        file.write(f"Average accuracy of {i}: {avg_class_accuracy[i]:.2f}%\n")
    file.write(f"Average F1 Score (Micro): {avg_f1_micro:.4f}\n")
    file.write(f"Average F1 Score (Macro): {avg_f1_macro:.4f}\n")
    file.write(f"Average F1 Score (Weighted): {avg_f1_weighted:.4f}\n")
    file.write(f"Average Jaccard Score (Micro): {avg_jaccard_micro:.4f}\n")
    file.write(f"Average Jaccard Score (Macro): {avg_jaccard_macro:.4f}\n")
    file.write(f"Average Jaccard Score (Weighted): {avg_jaccard_weighted:.4f}\n")
    file.write(f"Average MCC: {avg_mcc:.4f}\n")
    file.write(f"Average Hamming Loss: {avg_hamming_loss:.4f}\n")
    file.write(f"Cumulative Confusion Matrix: {aggregate_cm}\n")
    # Log the end time
    end_time = datetime.now()
    file.write(f"End time: {end_time}\n")

    # Optionally, you can also log the duration
    duration = end_time - start_time
    file.write(f"Duration: {duration}\n")

# %% [markdown]
# BiLSTM

# %%
# Log the start time
output_file_path = "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/Normal_Runs/bilstm_output.txt"
with open(output_file_path, 'w') as file:
    start_time = datetime.now()
    file.write(f"Start time: {start_time}\n")
    file.flush()

    # Load your data
    # current_dir = os.getcwd()
    # parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
    # embeddings_path = os.path.join(parent_dir, "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Embeddings_Mirella_Cut.json")

    # # Local Dataset
    # # current_dir = os.getcwd()
    # # parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
    # # embeddings_path = os.path.join(parent_dir, "Embeddings_5.5Seconds.json")

    # file.write('Opening file to read\n')
    # with open(embeddings_path, 'r') as f:
    #     data = json.load(f)

    # file_names = [entry['fileName'] for entry in data]
    # numpy_arrays = [np.array(entry['numpyArray']) for entry in data]
    # tensor_arrays = [torch.tensor(arr).float() for arr in numpy_arrays]
    # file.write('File has been read\n')
    # file.flush()
    # device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # class_names = []
    # tensor_arrays_balanced = []

    # for i, file_name in enumerate(file_names):
    #     if ('MC01' in file_name or 'FCO1' in file_name or 'MC04/Session2' in file_name):
    #         class_names.append('Healthy')
    #         tensor_arrays_balanced.append(tensor_arrays[i])
    #     elif ('F04' in file_name or 'M03' in file_name):
    #         class_names.append('VeryLow')
    #         tensor_arrays_balanced.append(tensor_arrays[i])
    #     elif ('F01' in file_name or 'M05' in file_name or 'F03/Session2' in file_name or 'F03/Session3' in file_name ):
    #         class_names.append('Low')
    #         tensor_arrays_balanced.append(tensor_arrays[i])
    #     elif ('M01' in file_name or 'M01' in file_name or 'M02' in file_name or 'M04' in file_name):
    #         class_names.append('Medium')
    #         tensor_arrays_balanced.append(tensor_arrays[i])

    # tensor_arrays = tensor_arrays_balanced

    # unique_class_names = ['Healthy', 'Low', 'VeryLow', 'Medium']
    # class_to_number = {class_name: i for i, class_name in enumerate(unique_class_names)}
    # class_numbers = [class_to_number[name] for name in class_names]

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    if torch.cuda.is_available():
        file.write("RUNNING ON GPU\n")
        file.flush()

    else:
        file.write("Running ON CPU\n")
        file.flush()

    class CustomEmbeddingDataset(Dataset):
        def __init__(self, embeddings, class_numbers):
            self.embeddings = embeddings
            self.class_numbers = class_numbers

        def __len__(self):
            return len(self.embeddings)

        def __getitem__(self, index):
            batch_embeddings = self.embeddings[index]
            batch_class_numbers = self.class_numbers[index]
            tensor_batch_class_numbers = torch.tensor(batch_class_numbers)
            return batch_embeddings, tensor_batch_class_numbers

    class RNN(nn.Module):
        def __init__(self, input_size, hidden_size, num_layers, num_classes):
            super(RNN, self).__init__()
            self.num_layers = num_layers
            self.hidden_size = hidden_size
            self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True)
            self.fc = nn.Linear(hidden_size * 2, num_classes)

        def forward(self, x):
            # Set initial hidden states (and cell states for LSTM)
            h0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size).to(device)

            # FOR LSTMs they also need an initial cell state so you need to add this as well
            c0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size).to(device)
            out, _ = self.lstm(x, (h0,c0))
            # Decode the hidden state of the last time step
            out = out[:, -1, :]
            # out: (n, 128)
            out = self.fc(out)
            # out: (n, 10)
            return out

    input_size = 1280
    hidden_size = 128
    num_layers = 2
    num_classes = 4
    num_epochs = 100
    batch_size = 4
    initial_learning_rate = 0.01
    patience = 13
    k_folds = 10
    # patience = 2
    # k_folds = 2
    sequence_length = 375

    kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

    dataset = CustomEmbeddingDataset(tensor_arrays, class_numbers)

    fold_results = []
    file.write("TRAINING THE MODEL\n")
    file.flush()
    aggregate_cm = np.zeros((num_classes, num_classes), dtype=int)


    for fold, (train_idx, test_idx) in enumerate(kf.split(dataset)):
        output_string = "FOLD NUMBER " + str(fold + 1) + "\n"
        file.write(output_string)
        file.flush()
        train_subset = Subset(dataset, train_idx)
        test_subset = Subset(dataset, test_idx)

        train_validation_x = [x[0] for x in train_subset]
        train_validation_y = [x[1].item() for x in train_subset]
        x_test = [x[0] for x in test_subset]
        y_test = [x[1].item() for x in test_subset]
        x_train, x_validation, y_train, y_validation = train_test_split(train_validation_x, train_validation_y, test_size=0.1, random_state=42)

        train_data_set = CustomEmbeddingDataset(x_train, y_train)
        validation_data_set = CustomEmbeddingDataset(x_validation, y_validation)
        test_data_set = CustomEmbeddingDataset(x_test, y_test)

        train_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True)
        validation_loader = DataLoader(validation_data_set, batch_size=batch_size, shuffle=False)
        test_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=False)

        model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=initial_learning_rate)

        scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=4, min_lr=0.00001)

        best_val_loss = float('inf')
        best_epoch = 0

        for epoch in range(num_epochs):
            model.train()
            total_loss = 0
            for images, labels in train_loader:
                images = images.reshape(-1, sequence_length, input_size).to(device)
                labels = labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()

            model.eval()
            val_loss = 0
            y_true_val, y_pred_val = [], []
            n_correct_val = 0
            n_samples_val = 0
            n_class_correct_val = [0 for _ in range(num_classes)]
            n_class_samples_val = [0 for _ in range(num_classes)]
            with torch.no_grad():
                for images, labels in validation_loader:
                    images = images.reshape(-1, sequence_length, input_size).to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    val_loss += loss.item()

                    _, predicted = torch.max(outputs, 1)
                    y_true_val.extend(labels.cpu().numpy())
                    y_pred_val.extend(predicted.cpu().numpy())

                    n_samples_val += labels.size(0)
                    n_correct_val += (predicted == labels).sum().item()
                    for i in range(len(labels)):
                        label = labels[i].item()
                        pred = predicted[i].item()
                        if label == pred:
                            n_class_correct_val[label] += 1
                        n_class_samples_val[label] += 1

            y_true, y_pred = [], []
            n_correct = 0
            n_samples = 0
            n_class_correct = [0 for _ in range(num_classes)]
            n_class_samples = [0 for _ in range(num_classes)]
            with torch.no_grad():
                for images, labels in test_loader:
                    images = images.reshape(-1, sequence_length, input_size).to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    _, predicted = torch.max(outputs, 1)
                    y_true.extend(labels.cpu().numpy())
                    y_pred.extend(predicted.cpu().numpy())

                    n_samples += labels.size(0)
                    n_correct += (predicted == labels).sum().item()
                    for i in range(len(labels)):
                        label = labels[i].item()
                        pred = predicted[i].item()
                        if label == pred:
                            n_class_correct[label] += 1
                        n_class_samples[label] += 1

            val_loss /= len(validation_loader)
            acc = 100.0 * n_correct / n_samples
            acc_val = 100.0 * n_correct_val / n_samples_val
            file.write(f"Epoch {epoch+1}, Validation Loss: {val_loss:.4f}, Learning Rate: {optimizer.param_groups[0]['lr']}\n")
            file.write(f"Test Accuracy of the network: {acc} %\n")
            file.write(f"Validation Accuracy of the network: {acc_val} %\n")
            current_time = datetime.now()
            file.write(f"Start time: {current_time}\n")
            file.flush()

            scheduler.step(val_loss)

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_epoch = epoch
                torch.save(model.state_dict(), f'BiLSTM_best_model_fold_{fold}.pth')
            elif epoch - best_epoch >= patience:
                file.write(f"Early stopping at epoch {epoch + 1}\n")
                file.flush()
                break

        model.load_state_dict(torch.load(f"BiLSTM_best_model_fold_{fold}.pth"))

        # Evaluation
        model.eval()
        y_true, y_pred = [], []
        n_correct = 0
        n_samples = 0
        n_class_correct = [0 for _ in range(num_classes)]
        n_class_samples = [0 for _ in range(num_classes)]
        with torch.no_grad():
            for images, labels in test_loader:
                images = images.reshape(-1, sequence_length, input_size).to(device)
                labels = labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs, 1)
                y_true.extend(labels.cpu().numpy())
                y_pred.extend(predicted.cpu().numpy())

                n_samples += labels.size(0)
                n_correct += (predicted == labels).sum().item()
                for i in range(len(labels)):
                    label = labels[i].item()
                    pred = predicted[i].item()
                    if label == pred:
                        n_class_correct[label] += 1
                    n_class_samples[label] += 1

            acc = 100.0 * n_correct / n_samples
            file.write(f"Accuracy of the network: {acc} %\n")
            file.flush()

            class_accs = []
            for i in range(num_classes):
                if n_class_samples[i] != 0:
                    current_acc = 100.0 * n_class_correct[i] / n_class_samples[i]
                    class_accs.append(current_acc)
                    file.write(f"Accuracy of {i}: {current_acc} %\n")
                    file.flush()
                else:
                    class_accs.append(0.0)
                    file.write(f"Accuracy of {i}: No samples\n")
                    file.flush()

        f1_micro = f1_score(y_true, y_pred, average='micro')
        f1_macro = f1_score(y_true, y_pred, average='macro')
        f1_weighted = f1_score(y_true, y_pred, average='weighted')
        jaccard_micro = jaccard_score(y_true, y_pred, average='micro')
        jaccard_macro = jaccard_score(y_true, y_pred, average='macro')
        jaccard_weighted = jaccard_score(y_true, y_pred, average='weighted')
        lb = LabelBinarizer()
        y_true_bin = lb.fit_transform(y_true)
        y_pred_bin = lb.transform(y_pred)
        mccs = [matthews_corrcoef(y_true_bin[:, i], y_pred_bin[:, i]) for i in range(len(lb.classes_))]
        average_mcc = sum(mccs) / len(mccs)
        hl = hamming_loss(y_true_bin, y_pred_bin)
        cm = confusion_matrix(y_true, y_pred)
        file.write(f"Fold: {fold}\n")
        file.write(f"Confusion Matrix:\n{cm}\n")
        file.write(f"Accuracy: {acc:.2f}%\n")
        file.write(f"F1 Micro: {f1_micro:.4f}\n")
        file.write(f"F1 Macro: {f1_macro:.4f}\n")
        file.write(f"F1 Weighted: {f1_weighted:.4f}\n")
        file.write(f"Jaccard Micro: {jaccard_micro:.4f}\n")
        file.write(f"Jaccard Macro: {jaccard_macro:.4f}\n")
        file.write(f"Jaccard Weighted: {jaccard_weighted:.4f}\n")
        file.write(f"MCC: {average_mcc:.4f}\n")
        file.write(f"Hamming Loss: {hl:.4f}\n")
        file.flush()

        aggregate_cm += cm

        fold_results.append({
            'fold': fold,
            'accuracy': acc,
            'class_accuracy': class_accs,
            'f1_micro': f1_micro,
            'f1_macro': f1_macro,
            'f1_weighted': f1_weighted,
            'jaccard_micro': jaccard_micro,
            'jaccard_macro': jaccard_macro,
            'jaccard_weighted': jaccard_weighted,
            'mcc': average_mcc,
            'hamming_loss': hl
        })

    # Compute and print the average metrics
    avg_accuracy = sum(result['accuracy'] for result in fold_results) / k_folds
    avg_class_accuracy = [sum(result['class_accuracy'][i] for result in fold_results) / k_folds for i in range(num_classes)]
    avg_f1_micro = sum(result['f1_micro'] for result in fold_results) / k_folds
    avg_f1_macro = sum(result['f1_macro'] for result in fold_results) / k_folds
    avg_f1_weighted = sum(result['f1_weighted'] for result in fold_results) / k_folds
    avg_jaccard_micro = sum(result['jaccard_micro'] for result in fold_results) / k_folds
    avg_jaccard_macro = sum(result['jaccard_macro'] for result in fold_results) / k_folds
    avg_jaccard_weighted = sum(result['jaccard_weighted'] for result in fold_results) / k_folds
    avg_mcc = sum(result['mcc'] for result in fold_results) / k_folds
    avg_hamming_loss = sum(result['hamming_loss'] for result in fold_results) / k_folds

    file.write(f"Average accuracy: {avg_accuracy:.2f}%\n")
    file.flush()
    for i in range(num_classes):
        file.write(f"Average accuracy of {i}: {avg_class_accuracy[i]:.2f}%\n")
    file.write(f"Average F1 Score (Micro): {avg_f1_micro:.4f}\n")
    file.write(f"Average F1 Score (Macro): {avg_f1_macro:.4f}\n")
    file.write(f"Average F1 Score (Weighted): {avg_f1_weighted:.4f}\n")
    file.write(f"Average Jaccard Score (Micro): {avg_jaccard_micro:.4f}\n")
    file.write(f"Average Jaccard Score (Macro): {avg_jaccard_macro:.4f}\n")
    file.write(f"Average Jaccard Score (Weighted): {avg_jaccard_weighted:.4f}\n")
    file.write(f"Average MCC: {avg_mcc:.4f}\n")
    file.write(f"Average Hamming Loss: {avg_hamming_loss:.4f}\n")
    file.write(f"Cumulative Confusion Matrix: {aggregate_cm}\n")
    # Log the end time
    end_time = datetime.now()
    file.write(f"End time: {end_time}\n")

    # Optionally, you can also log the duration
    duration = end_time - start_time
    file.write(f"Duration: {duration}\n")

# %%
output_file_path = "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/Normal_Runs/cnn_output.txt"
# Log the start time
with open(output_file_path, 'w') as file:
    start_time = datetime.now()
    file.write(f"Start time: {start_time}\n")
    file.flush()

    # Load your data
    current_dir = os.getcwd()
    parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
    embeddings_path = os.path.join(parent_dir, "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Embeddings_Normal_Cut_New.json")

    # Local Dataset
    # current_dir = os.getcwd()
    # parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
    # embeddings_path = os.path.join(parent_dir, "Embeddings_5.5Seconds.json")

    file.write('Opening file to read\n')
    with open(embeddings_path, 'r') as f:
        data = json.load(f)

    file_names = [entry['fileName'] for entry in data]
    # numpy_arrays = [np.array(entry['numpyArray']) for entry in data]
    # tensor_arrays = [torch.tensor(arr).float() for arr in numpy_arrays]
    tensor_arrays = [torch.tensor(np.array(entry['numpyArray'])).float() for entry in data]
    file.write('File has been read\n')
    file.flush()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    class_names = []
    tensor_arrays_balanced = []

    for i, file_name in enumerate(file_names):
      if ('MC01' in file_name or 'FCO1' in file_name or 'MC04/Session1' in file_name):
          class_names.append('Healthy')
          tensor_arrays_balanced.append(tensor_arrays[i])
      elif ('F04' in file_name or 'M03' in file_name):
          class_names.append('VeryLow')
          tensor_arrays_balanced.append(tensor_arrays[i])
      elif ('M05' in file_name or 'F03' in file_name ):
          class_names.append('Low')
          tensor_arrays_balanced.append(tensor_arrays[i])
      elif ('F01' in file_name or 'M01' in file_name
            or 'M02' in file_name or 'M04' in file_name):
          class_names.append('Medium')
          tensor_arrays_balanced.append(tensor_arrays[i])

    tensor_arrays = tensor_arrays_balanced
    # tensor_arrays.to(device)
    unique_class_names = ['Healthy', 'Low', 'VeryLow', 'Medium']
    class_to_number = {class_name: i for i, class_name in enumerate(unique_class_names)}
    class_numbers = [class_to_number[name] for name in class_names]

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    if torch.cuda.is_available():
        file.write("RUNNING ON GPU\n")
        file.flush()

    else:
        file.write("Running ON CPU\n")
        file.flush()

    class CustomEmbeddingDataset(Dataset):
        def __init__(self, embeddings, class_numbers):
            self.embeddings = embeddings
            self.class_numbers = class_numbers

        def __len__(self):
            return len(self.embeddings)

        def __getitem__(self, index):
            batch_embeddings = self.embeddings[index]
            batch_class_numbers = self.class_numbers[index]
            tensor_batch_class_numbers = torch.tensor(batch_class_numbers)
            return batch_embeddings, tensor_batch_class_numbers

    class ConvNet(nn.Module):
        def __init__(self):
            super(ConvNet, self).__init__()
            # 1 since only black and white input of image
            # 6 is the number of outputs
            # 5 is the kernel size
            self.conv1 = nn.Conv2d(1, 16, kernel_size = 3)
            # width = (125 - 3) / 1 + 1= 123
            # height = (1280 -3) / 1  + 1= 1278
            self.pool = nn.MaxPool2d(kernel_size=2, stride = 2)
            # width = roundDown((123 - 2) / 2) + 1 = 61
            # height = roundDown((1278 - 2 ) / 2) + 1 = 639
            self.conv2 = nn.Conv2d(16, 32, kernel_size = 3)
            # width = (61 - 3) / 1 + 1 = 59
            # height = (639 - 3) / 1  + 1 = 637

            # apply pool again
            # width = roundDown((59 - 2) / 2)  + 1 = 29
            # height = roundDown(637 - 2) / 2 + 1) = 318

            self.conv3 = nn.Conv2d(32, 64, kernel_size = 5)
            # width = (29 - 5) / 1 + 1 = 25
            # height = (318 - 5) / 1 + 1 = 314

            # apply pool again
            # width = roundDown((25 - 2) / 2)  + 1  = 12
            # height = (314 - 2) / 2 + 1 = 157

            self.conv4 = nn.Conv2d(64, 128, kernel_size = 5)
            # width = roundDown(12 - 5) / 1)  + 1  = 8
            # height = (157 -5) / 1 + 1 = 153

            # apply pool again
            # width = roundDown((8 -2) / 2) + 1 = 4
            # height = roundDown((153 - 2) / 2 ) + 1 = 76

            self.fc1 = nn.Linear(4 * 76 * 128, 4)

        def forward(self, x):
            # -> n, 3, 32, 32
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            x = self.pool(F.relu(self.conv3(x)))
            x = self.pool(F.relu(self.conv4(x)))

            x = x.view(-1, 4 * 76 * 128)
            # x = F.softmax(self.fc1(x))
            x = self.fc1(x)
            return x

    input_size = 1280
    hidden_size = 128
    num_layers = 2
    num_classes = 4
    num_epochs = 100
    batch_size = 4
    initial_learning_rate = 0.01
    patience = 18
    k_folds = 10
    # patience = 2
    # k_folds = 2
    sequence_length = 375
    aggregate_cm = np.zeros((num_classes, num_classes), dtype=int)

    kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

    dataset = CustomEmbeddingDataset(tensor_arrays, class_numbers)

    fold_results = []
    file.write("TRAINING THE MODEL\n")
    file.flush()

    for fold, (train_idx, test_idx) in enumerate(kf.split(dataset)):
        output_string = "FOLD NUMBER " + str(fold + 1) + "\n"
        file.write(output_string)
        file.flush()
        train_subset = Subset(dataset, train_idx)
        test_subset = Subset(dataset, test_idx)

        train_validation_x = [x[0] for x in train_subset]
        train_validation_y = [x[1].item() for x in train_subset]
        x_test = [x[0] for x in test_subset]
        y_test = [x[1].item() for x in test_subset]
        x_train, x_validation, y_train, y_validation = train_test_split(train_validation_x, train_validation_y, test_size=0.1, random_state=42)

        train_data_set = CustomEmbeddingDataset(x_train, y_train)
        validation_data_set = CustomEmbeddingDataset(x_validation, y_validation)
        test_data_set = CustomEmbeddingDataset(x_test, y_test)

        train_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True)
        validation_loader = DataLoader(validation_data_set, batch_size=batch_size, shuffle=False)
        test_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=False)

        model = ConvNet().to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.SGD(model.parameters(), lr=initial_learning_rate)

        scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=6, min_lr=0.00001)

        best_val_loss = float('inf')
        best_epoch = 0

        for epoch in range(num_epochs):
            model.train()
            total_loss = 0
            for images, labels in train_loader:
                images = images.unsqueeze(1).to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)

                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss = total_loss + loss.item()

            model.eval()
            val_loss = 0
            y_true_val, y_pred_val = [], []
            n_correct_val = 0
            n_samples_val = 0
            n_class_correct_val = [0 for _ in range(num_classes)]
            n_class_samples_val = [0 for _ in range(num_classes)]
            with torch.no_grad():
                for images, labels in validation_loader:
                    images = images.unsqueeze(1).to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    val_loss = val_loss + loss.item()
                    _, predicted = torch.max(outputs, 1)
                    y_true_val.extend(labels.cpu().numpy())
                    y_pred_val.extend(predicted.cpu().numpy())

                    n_samples_val += labels.size(0)
                    n_correct_val += (predicted == labels).sum().item()
                    for i in range(len(labels)):
                        label = labels[i].item()
                        pred = predicted[i].item()
                        if label == pred:
                            n_class_correct_val[label] += 1
                        n_class_samples_val[label] += 1

            model.eval()
            y_true, y_pred = [], []
            n_correct = 0
            n_samples = 0
            n_class_correct = [0 for _ in range(num_classes)]
            n_class_samples = [0 for _ in range(num_classes)]
            with torch.no_grad():
                for images, labels in test_loader:
                    images = images.unsqueeze(1)
                    images = images.to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    # max returns (value ,index)
                    _, predicted = torch.max(outputs, 1)
                    y_true.extend(labels.cpu().numpy())
                    y_pred.extend(predicted.cpu().numpy())

                    n_samples += labels.size(0)
                    n_correct += (predicted == labels).sum().item()
                    for i in range(len(labels)):
                        label = labels[i].item()
                        pred = predicted[i].item()
                        if label == pred:
                            n_class_correct[label] += 1
                        n_class_samples[label] += 1

            acc = 100.0 * n_correct / n_samples
            file.write(f"Test Accuracy of the network: {acc} %\n")
            file.flush()
            acc_val = 100.0 * n_correct_val / n_samples_val
            file.write(f"Validation Accuracy of the network: {acc_val} %\n")

            val_loss /= len(validation_loader)
            file.write(f"Epoch {epoch+1}, Validation Loss: {val_loss:.4f}, Learning Rate: {optimizer.param_groups[0]['lr']}\n")
            current_time = datetime.now()
            file.write(f"Start time: {current_time}\n")
            file.flush()

            scheduler.step(val_loss)

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_epoch = epoch
                torch.save(model.state_dict(), f'CNN_best_model_fold_{fold}.pth')
            elif epoch - best_epoch >= patience:
                file.write(f"Early stopping at epoch {epoch + 1}\n")
                file.flush()
                break

        model.load_state_dict(torch.load(f"CNN_best_model_fold_{fold}.pth"))

        # Evaluation
        model.eval()
        y_true, y_pred = [], []
        n_correct = 0
        n_samples = 0
        n_class_correct = [0 for _ in range(num_classes)]
        n_class_samples = [0 for _ in range(num_classes)]
        with torch.no_grad():
            for images, labels in test_loader:
                images = images.unsqueeze(1)
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                # max returns (value ,index)
                _, predicted = torch.max(outputs, 1)
                y_true.extend(labels.cpu().numpy())
                y_pred.extend(predicted.cpu().numpy())

                n_samples += labels.size(0)
                n_correct += (predicted == labels).sum().item()
                for i in range(len(labels)):
                    label = labels[i].item()
                    pred = predicted[i].item()
                    if label == pred:
                        n_class_correct[label] += 1
                    n_class_samples[label] += 1

            acc = 100.0 * n_correct / n_samples
            file.write(f"Accuracy of the network: {acc} %\n")
            file.flush()

            class_accs = []
            for i in range(num_classes):
                if n_class_samples[i] != 0:
                    current_acc = 100.0 * n_class_correct[i] / n_class_samples[i]
                    class_accs.append(current_acc)
                    file.write(f"Accuracy of {unique_class_names[i]}: {current_acc} %\n")
                    file.flush()
                else:
                    class_accs.append(0.0)
                    file.write(f"Accuracy of {unique_class_names[i]}: No samples\n")
                    file.flush()

        cm = confusion_matrix(y_true, y_pred)
        f1_micro = f1_score(y_true, y_pred, average='micro')
        f1_macro = f1_score(y_true, y_pred, average='macro')
        f1_weighted = f1_score(y_true, y_pred, average='weighted')
        jaccard_micro = jaccard_score(y_true, y_pred, average='micro')
        jaccard_macro = jaccard_score(y_true, y_pred, average='macro')
        jaccard_weighted = jaccard_score(y_true, y_pred, average='weighted')
        lb = LabelBinarizer()
        y_true_bin = lb.fit_transform(y_true)
        y_pred_bin = lb.transform(y_pred)
        mccs = [matthews_corrcoef(y_true_bin[:, i], y_pred_bin[:, i]) for i in range(len(lb.classes_))]
        average_mcc = sum(mccs) / len(mccs)
        hl = hamming_loss(y_true_bin, y_pred_bin)

        file.write(f"Fold: {fold}\n")
        file.write(f"Confusion Matrix:\n{cm}\n")
        file.write(f"Accuracy: {acc:.2f}%\n")
        file.write(f"F1 Micro: {f1_micro:.4f}\n")
        file.write(f"F1 Macro: {f1_macro:.4f}\n")
        file.write(f"F1 Weighted: {f1_weighted:.4f}\n")
        file.write(f"Jaccard Micro: {jaccard_micro:.4f}\n")
        file.write(f"Jaccard Macro: {jaccard_macro:.4f}\n")
        file.write(f"Jaccard Weighted: {jaccard_weighted:.4f}\n")
        file.write(f"MCC: {average_mcc:.4f}\n")
        file.write(f"Hamming Loss: {hl:.4f}\n")
        file.flush()

        aggregate_cm += cm
        fold_results.append({
            'fold': fold,
            'accuracy': acc,
            'class_accuracy': class_accs,
            'f1_micro': f1_micro,
            'f1_macro': f1_macro,
            'f1_weighted': f1_weighted,
            'jaccard_micro': jaccard_micro,
            'jaccard_macro': jaccard_macro,
            'jaccard_weighted': jaccard_weighted,
            'mcc': average_mcc,
            'hamming_loss': hl
        })

    # Compute and print the average metrics
    avg_accuracy = sum(result['accuracy'] for result in fold_results) / k_folds
    avg_class_accuracy = [sum(result['class_accuracy'][i] for result in fold_results) / k_folds for i in range(num_classes)]
    avg_f1_micro = sum(result['f1_micro'] for result in fold_results) / k_folds
    avg_f1_macro = sum(result['f1_macro'] for result in fold_results) / k_folds
    avg_f1_weighted = sum(result['f1_weighted'] for result in fold_results) / k_folds
    avg_jaccard_micro = sum(result['jaccard_micro'] for result in fold_results) / k_folds
    avg_jaccard_macro = sum(result['jaccard_macro'] for result in fold_results) / k_folds
    avg_jaccard_weighted = sum(result['jaccard_weighted'] for result in fold_results) / k_folds
    avg_mcc = sum(result['mcc'] for result in fold_results) / k_folds
    avg_hamming_loss = sum(result['hamming_loss'] for result in fold_results) / k_folds

    file.write(f"Average accuracy: {avg_accuracy:.2f}%\n")
    file.flush()
    for i in range(num_classes):
        file.write(f"Average accuracy of {unique_class_names[i]}: {avg_class_accuracy[i]:.2f}%\n")
    file.write(f"Average F1 Score (Micro): {avg_f1_micro:.4f}\n")
    file.write(f"Average F1 Score (Macro): {avg_f1_macro:.4f}\n")
    file.write(f"Average F1 Score (Weighted): {avg_f1_weighted:.4f}\n")
    file.write(f"Average Jaccard Score (Micro): {avg_jaccard_micro:.4f}\n")
    file.write(f"Average Jaccard Score (Macro): {avg_jaccard_macro:.4f}\n")
    file.write(f"Average Jaccard Score (Weighted): {avg_jaccard_weighted:.4f}\n")
    file.write(f"Average MCC: {avg_mcc:.4f}\n")
    file.write(f"Average Hamming Loss: {avg_hamming_loss:.4f}\n")
    file.write(f"Cumulative Confusion Matrix: {aggregate_cm}\n")

    # Log the end time
    end_time = datetime.now()
    file.write(f"End time: {end_time}\n")

    # Optionally, you can also log the duration
    duration = end_time - start_time
    file.write(f"Duration: {duration}\n")

# %%
import torch
import torch.nn as nn
import numpy as np
import json
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import f1_score, jaccard_score, matthews_corrcoef, hamming_loss
from sklearn.preprocessing import LabelBinarizer
import os
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import time
from datetime import datetime
import torch.nn.functional as F

# %%
output_file_path = "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/Normal_Runs/cnn_output.txt"
# Log the start time
with open(output_file_path, 'w') as file:
    start_time = datetime.now()
    file.write(f"Start time: {start_time}\n")
    file.flush()

    # # Load your data
    # current_dir = os.getcwd()
    # parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
    # embeddings_path = os.path.join(parent_dir, "/content/drive/My Drive/CSE/Year 3/ResearchProject/Dataset/TORGO_Embeddings_Normal_Cut_New.json")

    # # Local Dataset
    # # current_dir = os.getcwd()
    # # parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
    # # embeddings_path = os.path.join(parent_dir, "Embeddings_5.5Seconds.json")

    # file.write('Opening file to read\n')
    # with open(embeddings_path, 'r') as f:
    #     data = json.load(f)

    # file_names = [entry['fileName'] for entry in data]
    # # numpy_arrays = [np.array(entry['numpyArray']) for entry in data]
    # # tensor_arrays = [torch.tensor(arr).float() for arr in numpy_arrays]
    # tensor_arrays = [torch.tensor(np.array(entry['numpyArray'])).float() for entry in data]
    # file.write('File has been read\n')
    # file.flush()
    # device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # class_names = []
    # tensor_arrays_balanced = []

    # for i, file_name in enumerate(file_names):
    #   if ('MC01' in file_name or 'FCO1' in file_name or 'MC04/Session1' in file_name):
    #       class_names.append('Healthy')
    #       tensor_arrays_balanced.append(tensor_arrays[i])
    #   elif ('F04' in file_name or 'M03' in file_name):
    #       class_names.append('VeryLow')
    #       tensor_arrays_balanced.append(tensor_arrays[i])
    #   elif ('M05' in file_name or 'F03' in file_name ):
    #       class_names.append('Low')
    #       tensor_arrays_balanced.append(tensor_arrays[i])
    #   elif ('F01' in file_name or 'M01' in file_name
    #         or 'M02' in file_name or 'M04' in file_name):
    #       class_names.append('Medium')
    #       tensor_arrays_balanced.append(tensor_arrays[i])

    # tensor_arrays = tensor_arrays_balanced
    # # tensor_arrays.to(device)
    # unique_class_names = ['Healthy', 'Low', 'VeryLow', 'Medium']
    # class_to_number = {class_name: i for i, class_name in enumerate(unique_class_names)}
    # class_numbers = [class_to_number[name] for name in class_names]

    # device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    if torch.cuda.is_available():
        file.write("RUNNING ON GPU\n")
        file.flush()

    else:
        file.write("Running ON CPU\n")
        file.flush()

    class CustomEmbeddingDataset(Dataset):
        def __init__(self, embeddings, class_numbers):
            self.embeddings = embeddings
            self.class_numbers = class_numbers

        def __len__(self):
            return len(self.embeddings)

        def __getitem__(self, index):
            batch_embeddings = self.embeddings[index]
            batch_class_numbers = self.class_numbers[index]
            tensor_batch_class_numbers = torch.tensor(batch_class_numbers)
            return batch_embeddings, tensor_batch_class_numbers

    class ConvNet(nn.Module):
        def __init__(self):
            super(ConvNet, self).__init__()
            # 1 since only black and white input of image
            # 6 is the number of outputs
            # 5 is the kernel size
            self.conv1 = nn.Conv2d(1, 16, kernel_size = 3)
            # width = (375 - 3) / 1 + 1= 373
            # height = (1280 -3) / 1  + 1= 1278
            self.pool = nn.MaxPool2d(kernel_size=2, stride = 2)
            # width = roundDown((373 - 2) / 2) + 1 = 186
            # height = roundDown((1278 - 2 ) / 2) + 1 = 639
            self.conv2 = nn.Conv2d(16, 32, kernel_size = 3)
            # width = (186 - 3) / 1 + 1 = 184
            # height = (639 - 3) / 1  + 1 = 637

            # apply pool again
            # width = roundDown((184 - 2) / 2)  + 1 = 92
            # height = roundDown(637 - 2) / 2 + 1) = 318

            self.conv3 = nn.Conv2d(32, 64, kernel_size = 5)
            # width = (92 - 5) / 1 + 1 = 88
            # height = (318 - 5) / 1 + 1 = 314

            # apply pool again
            # width = roundDown((88 - 2) / 2)  + 1  = 44
            # height = (314 - 2) / 2 + 1 = 157

            self.conv4 = nn.Conv2d(64, 128, kernel_size = 5)
            # width = roundDown(44 - 5) / 1)  + 1  = 40
            # height = (157 -5) / 1 + 1 = 153

            # apply pool again
            # width = roundDown((40 -2) / 2) + 1 = 20
            # height = roundDown((153 - 2) / 2 ) + 1 = 76

            self.fc1 = nn.Linear(20 * 76 * 128, 4)

        def forward(self, x):
            # -> n, 3, 32, 32
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            x = self.pool(F.relu(self.conv3(x)))
            x = self.pool(F.relu(self.conv4(x)))

            x = x.view(-1, 20 * 76 * 128)
            # x = F.softmax(self.fc1(x))
            x = self.fc1(x)
            return x

    input_size = 1280
    hidden_size = 128
    num_layers = 2
    num_classes = 4
    num_epochs = 100
    batch_size = 4
    initial_learning_rate = 0.01
    patience = 18
    k_folds = 10
    # patience = 2
    # k_folds = 2
    sequence_length = 375
    aggregate_cm = np.zeros((num_classes, num_classes), dtype=int)

    kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

    dataset = CustomEmbeddingDataset(tensor_arrays, class_numbers)

    fold_results = []
    file.write("TRAINING THE MODEL\n")
    file.flush()

    for fold, (train_idx, test_idx) in enumerate(kf.split(dataset)):
        output_string = "FOLD NUMBER " + str(fold + 1) + "\n"
        file.write(output_string)
        file.flush()
        train_subset = Subset(dataset, train_idx)
        test_subset = Subset(dataset, test_idx)

        train_validation_x = [x[0] for x in train_subset]
        train_validation_y = [x[1].item() for x in train_subset]
        x_test = [x[0] for x in test_subset]
        y_test = [x[1].item() for x in test_subset]
        x_train, x_validation, y_train, y_validation = train_test_split(train_validation_x, train_validation_y, test_size=0.1, random_state=42)

        train_data_set = CustomEmbeddingDataset(x_train, y_train)
        validation_data_set = CustomEmbeddingDataset(x_validation, y_validation)
        test_data_set = CustomEmbeddingDataset(x_test, y_test)

        train_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True)
        validation_loader = DataLoader(validation_data_set, batch_size=batch_size, shuffle=False)
        test_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=False)

        model = ConvNet().to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.SGD(model.parameters(), lr=initial_learning_rate)

        scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=6, min_lr=0.00001)

        best_val_loss = float('inf')
        best_epoch = 0

        for epoch in range(num_epochs):
            model.train()
            total_loss = 0
            for images, labels in train_loader:
                images = images.unsqueeze(1).to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)

                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss = total_loss + loss.item()

            model.eval()
            val_loss = 0
            y_true_val, y_pred_val = [], []
            n_correct_val = 0
            n_samples_val = 0
            n_class_correct_val = [0 for _ in range(num_classes)]
            n_class_samples_val = [0 for _ in range(num_classes)]
            with torch.no_grad():
                for images, labels in validation_loader:
                    images = images.unsqueeze(1).to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    val_loss = val_loss + loss.item()
                    _, predicted = torch.max(outputs, 1)
                    y_true_val.extend(labels.cpu().numpy())
                    y_pred_val.extend(predicted.cpu().numpy())

                    n_samples_val += labels.size(0)
                    n_correct_val += (predicted == labels).sum().item()
                    for i in range(len(labels)):
                        label = labels[i].item()
                        pred = predicted[i].item()
                        if label == pred:
                            n_class_correct_val[label] += 1
                        n_class_samples_val[label] += 1

            model.eval()
            y_true, y_pred = [], []
            n_correct = 0
            n_samples = 0
            n_class_correct = [0 for _ in range(num_classes)]
            n_class_samples = [0 for _ in range(num_classes)]
            with torch.no_grad():
                for images, labels in test_loader:
                    images = images.unsqueeze(1)
                    images = images.to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    # max returns (value ,index)
                    _, predicted = torch.max(outputs, 1)
                    y_true.extend(labels.cpu().numpy())
                    y_pred.extend(predicted.cpu().numpy())

                    n_samples += labels.size(0)
                    n_correct += (predicted == labels).sum().item()
                    for i in range(len(labels)):
                        label = labels[i].item()
                        pred = predicted[i].item()
                        if label == pred:
                            n_class_correct[label] += 1
                        n_class_samples[label] += 1

            acc = 100.0 * n_correct / n_samples
            file.write(f"Test Accuracy of the network: {acc} %\n")
            file.flush()
            acc_val = 100.0 * n_correct_val / n_samples_val
            file.write(f"Validation Accuracy of the network: {acc_val} %\n")

            val_loss /= len(validation_loader)
            file.write(f"Epoch {epoch+1}, Validation Loss: {val_loss:.4f}, Learning Rate: {optimizer.param_groups[0]['lr']}\n")
            current_time = datetime.now()
            file.write(f"Start time: {current_time}\n")
            file.flush()

            scheduler.step(val_loss)

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_epoch = epoch
                torch.save(model.state_dict(), f'CNN_best_model_fold_{fold}.pth')
            elif epoch - best_epoch >= patience:
                file.write(f"Early stopping at epoch {epoch + 1}\n")
                file.flush()
                break

        model.load_state_dict(torch.load(f"CNN_best_model_fold_{fold}.pth"))

        # Evaluation
        model.eval()
        y_true, y_pred = [], []
        n_correct = 0
        n_samples = 0
        n_class_correct = [0 for _ in range(num_classes)]
        n_class_samples = [0 for _ in range(num_classes)]
        with torch.no_grad():
            for images, labels in test_loader:
                images = images.unsqueeze(1)
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                # max returns (value ,index)
                _, predicted = torch.max(outputs, 1)
                y_true.extend(labels.cpu().numpy())
                y_pred.extend(predicted.cpu().numpy())

                n_samples += labels.size(0)
                n_correct += (predicted == labels).sum().item()
                for i in range(len(labels)):
                    label = labels[i].item()
                    pred = predicted[i].item()
                    if label == pred:
                        n_class_correct[label] += 1
                    n_class_samples[label] += 1

            acc = 100.0 * n_correct / n_samples
            file.write(f"Accuracy of the network: {acc} %\n")
            file.flush()

            class_accs = []
            for i in range(num_classes):
                if n_class_samples[i] != 0:
                    current_acc = 100.0 * n_class_correct[i] / n_class_samples[i]
                    class_accs.append(current_acc)
                    file.write(f"Accuracy of {unique_class_names[i]}: {current_acc} %\n")
                    file.flush()
                else:
                    class_accs.append(0.0)
                    file.write(f"Accuracy of {unique_class_names[i]}: No samples\n")
                    file.flush()

        cm = confusion_matrix(y_true, y_pred)
        f1_micro = f1_score(y_true, y_pred, average='micro')
        f1_macro = f1_score(y_true, y_pred, average='macro')
        f1_weighted = f1_score(y_true, y_pred, average='weighted')
        jaccard_micro = jaccard_score(y_true, y_pred, average='micro')
        jaccard_macro = jaccard_score(y_true, y_pred, average='macro')
        jaccard_weighted = jaccard_score(y_true, y_pred, average='weighted')
        lb = LabelBinarizer()
        y_true_bin = lb.fit_transform(y_true)
        y_pred_bin = lb.transform(y_pred)
        mccs = [matthews_corrcoef(y_true_bin[:, i], y_pred_bin[:, i]) for i in range(len(lb.classes_))]
        average_mcc = sum(mccs) / len(mccs)
        hl = hamming_loss(y_true_bin, y_pred_bin)

        file.write(f"Fold: {fold}\n")
        file.write(f"Confusion Matrix:\n{cm}\n")
        file.write(f"Accuracy: {acc:.2f}%\n")
        file.write(f"F1 Micro: {f1_micro:.4f}\n")
        file.write(f"F1 Macro: {f1_macro:.4f}\n")
        file.write(f"F1 Weighted: {f1_weighted:.4f}\n")
        file.write(f"Jaccard Micro: {jaccard_micro:.4f}\n")
        file.write(f"Jaccard Macro: {jaccard_macro:.4f}\n")
        file.write(f"Jaccard Weighted: {jaccard_weighted:.4f}\n")
        file.write(f"MCC: {average_mcc:.4f}\n")
        file.write(f"Hamming Loss: {hl:.4f}\n")
        file.flush()

        aggregate_cm += cm
        fold_results.append({
            'fold': fold,
            'accuracy': acc,
            'class_accuracy': class_accs,
            'f1_micro': f1_micro,
            'f1_macro': f1_macro,
            'f1_weighted': f1_weighted,
            'jaccard_micro': jaccard_micro,
            'jaccard_macro': jaccard_macro,
            'jaccard_weighted': jaccard_weighted,
            'mcc': average_mcc,
            'hamming_loss': hl
        })

    # Compute and print the average metrics
    avg_accuracy = sum(result['accuracy'] for result in fold_results) / k_folds
    avg_class_accuracy = [sum(result['class_accuracy'][i] for result in fold_results) / k_folds for i in range(num_classes)]
    avg_f1_micro = sum(result['f1_micro'] for result in fold_results) / k_folds
    avg_f1_macro = sum(result['f1_macro'] for result in fold_results) / k_folds
    avg_f1_weighted = sum(result['f1_weighted'] for result in fold_results) / k_folds
    avg_jaccard_micro = sum(result['jaccard_micro'] for result in fold_results) / k_folds
    avg_jaccard_macro = sum(result['jaccard_macro'] for result in fold_results) / k_folds
    avg_jaccard_weighted = sum(result['jaccard_weighted'] for result in fold_results) / k_folds
    avg_mcc = sum(result['mcc'] for result in fold_results) / k_folds
    avg_hamming_loss = sum(result['hamming_loss'] for result in fold_results) / k_folds

    file.write(f"Average accuracy: {avg_accuracy:.2f}%\n")
    file.flush()
    for i in range(num_classes):
        file.write(f"Average accuracy of {unique_class_names[i]}: {avg_class_accuracy[i]:.2f}%\n")
    file.write(f"Average F1 Score (Micro): {avg_f1_micro:.4f}\n")
    file.write(f"Average F1 Score (Macro): {avg_f1_macro:.4f}\n")
    file.write(f"Average F1 Score (Weighted): {avg_f1_weighted:.4f}\n")
    file.write(f"Average Jaccard Score (Micro): {avg_jaccard_micro:.4f}\n")
    file.write(f"Average Jaccard Score (Macro): {avg_jaccard_macro:.4f}\n")
    file.write(f"Average Jaccard Score (Weighted): {avg_jaccard_weighted:.4f}\n")
    file.write(f"Average MCC: {avg_mcc:.4f}\n")
    file.write(f"Average Hamming Loss: {avg_hamming_loss:.4f}\n")
    file.write(f"Cumulative Confusion Matrix: {aggregate_cm}\n")

    # Log the end time
    end_time = datetime.now()
    file.write(f"End time: {end_time}\n")

    # Optionally, you can also log the duration
    duration = end_time - start_time
    file.write(f"Duration: {duration}\n")

# %%
from google.colab import drive
drive.mount('/content/drive')
